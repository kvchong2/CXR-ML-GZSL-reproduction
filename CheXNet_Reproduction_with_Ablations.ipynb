# %% [markdown]
# # Download Data Sources
#
# Download data sources from Box folder and store into our Google Drive.  Mount your Google Drive first and make a "project" folder under "MyDrive".

# %%
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/vfk49d74nhbxq3nqjg0900w5nvkorp5c.gz
# !mv drive/MyDrive/project/vfk49d74nhbxq3nqjg0900w5nvkorp5c.gz drive/MyDrive/project/images1.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/i28rlmbvmfjbl8p2n3ril0pptcmcu9d1.gz
# !mv drive/MyDrive/project/i28rlmbvmfjbl8p2n3ril0pptcmcu9d1.gz drive/MyDrive/project/images2.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/f1t00wrtdk94satdfb9olcolqx20z2jp.gz
# !mv drive/MyDrive/project/f1t00wrtdk94satdfb9olcolqx20z2jp.gz drive/MyDrive/project/images3.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/0aowwzs5lhjrceb3qp67ahp0rd1l1etg.gz
# !mv drive/MyDrive/project/0aowwzs5lhjrceb3qp67ahp0rd1l1etg.gz drive/MyDrive/project/images4.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/v5e3goj22zr6h8tzualxfsqlqaygfbsn.gz
# !mv drive/MyDrive/project/v5e3goj22zr6h8tzualxfsqlqaygfbsn.gz drive/MyDrive/project/images5.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/asi7ikud9jwnkrnkj99jnpfkjdes7l6l.gz
# !mv drive/MyDrive/project/asi7ikud9jwnkrnkj99jnpfkjdes7l6l.gz drive/MyDrive/project/images6.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/jn1b4mw4n6lnh74ovmcjb8y48h8xj07n.gz
# !mv drive/MyDrive/project/jn1b4mw4n6lnh74ovmcjb8y48h8xj07n.gz drive/MyDrive/project/images7.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/tvpxmn7qyrgl0w8wfh9kqfjskv6nmm1j.gz
# !mv drive/MyDrive/project/tvpxmn7qyrgl0w8wfh9kqfjskv6nmm1j.gz drive/MyDrive/project/images8.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/upyy3ml7qdumlgk2rfcvlb9k6gvqq2pj.gz
# !mv drive/MyDrive/project/upyy3ml7qdumlgk2rfcvlb9k6gvqq2pj.gz drive/MyDrive/project/images9.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/l6nilvfa9cg3s28tqv1qc1olm3gnz54p.gz
# !mv drive/MyDrive/project/l6nilvfa9cg3s28tqv1qc1olm3gnz54p.gz drive/MyDrive/project/images10.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/hhq8fkdgvcari67vfhs7ppg2w6ni4jze.gz
# !mv drive/MyDrive/project/hhq8fkdgvcari67vfhs7ppg2w6ni4jze.gz drive/MyDrive/project/images11.tar.gz
# !wget -P drive/MyDrive/project https://nihcc.box.com/shared/static/ioqwiy20ihqwyr8pf4c24eazhh281pbu.gz
# !mv drive/MyDrive/project/ioqwiy20ihqwyr8pf4c24eazhh281pbu.gz drive/MyDrive/project/images12.tar.gz

# %% [markdown]
# # Extract Images
#
# Extract the images into colab environment under CXR8.

# %%
# !tar xzf drive/MyDrive/project/images1.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images2.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images3.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images4.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images5.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images6.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images7.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images8.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images9.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images10.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images11.tar.gz -C drive/MyDrive/project/
# !tar xzf drive/MyDrive/project/images12.tar.gz -C drive/MyDrive/project/

# !mkdir -p CXR8
# !tar xzf drive/MyDrive/project/images1.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images2.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images3.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images4.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images5.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images6.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images7.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images8.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images9.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images10.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images11.tar.gz -C CXR8
# !tar xzf drive/MyDrive/project/images12.tar.gz -C CXR8

# %% [markdown]
# # Data Files
#
# Copy the other required data files (dataset splits, the BioBert embeddings, and the labels)
#
# Get the `Data_Entry_2017_v2020.csv` file from the Box folder (https://nihcc.app.box.com/v/ChestXray-NIHCC)
#
# The `dataset_splits` and `embeddings` are from the git repo (https://github.com/nyuad-cai/CXR-ML-GZSL)

# %%
# !cp -r drive/MyDrive/project/dataset_splits .
# !cp -r drive/MyDrive/project/embeddings .
# !cp -r drive/MyDrive/project/Data_Entry_2017_v2020.csv CXR8

# %% [markdown]
# # Install Packages

# %%
# !pip install torch torchvision numpy pandas scikit-learn matplotlib tqdm pillow
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
# Import all required libraries
# Standard library imports
import os  # File system operations
import numpy as np  # Numerical computations
import time  # Time tracking for training
import sys  # System-specific parameters
from datetime import datetime, timedelta  # Time calculations for ETA
from tqdm import tqdm  # Progress bars

# PyTorch core imports
import torch  # Main PyTorch library
import torch.backends.cudnn as cudnn  # CUDA optimizations
import torchvision.transforms as transforms  # Image preprocessing/augmentation
import torch.optim as optim  # Optimizers (Adam, SGD, etc.)
from torch.utils.data import DataLoader  # Data loading utilities
from torch.optim.lr_scheduler import ReduceLROnPlateau  # Learning rate scheduling

# Machine learning metrics
# from sklearn.metrics.ranking import roc_auc_score  # AUROC metric for evaluation
from sklearn.metrics import roc_auc_score  # AUROC metric for evaluation
from sklearn.metrics import accuracy_score  # Accuracy metric

# PyTorch functional operations
from torch.nn.functional import kl_div, softmax, log_softmax  # Loss functions and activations
from numpy import dot  # Dot product
from numpy.linalg import norm  # Vector norms

# Neural network components
import torch.nn as nn  # Neural network layers
import torchvision  # Pre-trained vision models (DenseNet, ResNet, etc.)
import torch.nn.functional as F  # Functional interface for neural network operations
from numpy import linalg as LA  # Linear algebra operations

# Data processing
from PIL import Image  # Image loading and manipulation
import pandas as pd  # Data manipulation (CSV reading)
import glob  # File path pattern matching
import matplotlib.pyplot as plt  # Plotting and visualization

# %% [markdown]
# ## Configuration Parameters

# %%
# Training Parameters (from train_densenet121.sh and arguments.py)
# This class replaces command-line arguments with a simple configuration object
class Args:
    def __init__(self):
        # Data paths - where to find the dataset and where to save outputs
        self.data_root = 'CXR8'  # Root directory of NIH Chest X-ray dataset
        self.save_dir = 'checkpoints'  # Directory to save model checkpoints
        self.train_file = 'dataset_splits/train.txt'  # List of training image filenames
        self.val_file = 'dataset_splits/val.txt'  # List of validation image filenames
        self.test_file = 'dataset_splits/test.txt'  # List of test image filenames

        # Model settings
        self.pretrained = True  # Use ImageNet pre-trained weights for the vision backbone
        self.bce_only = False  # If True, use only binary cross-entropy loss (no ZSL ranking loss)
        self.num_classes = 14  # Number of disease classes in the dataset
        self.batch_size = 16  # Number of images per training batch
        self.epochs = 40  # Total number of training epochs
        self.early_stopping_patience = 5  # Stop training if max_auroc_mean doesn't improve for this many epochs (None to disable)        self.vision_backbone = 'densenet121'  # Vision model architecture (densenet121, densenet169, etc.)
        self.vision_backbone = 'densenet121'  # Vision model architecture (densenet121, densenet169, etc.)
        self.resume_from = None  # Path to checkpoint to resume training from (includes optimizer state)
        self.load_from = None  # Path to checkpoint to load weights from (weights only, no optimizer state)

        # Image preprocessing - dimensions for image transformations
        self.resize = 256  # Size to resize images to before cropping
        self.crop = 224  # Final crop size (standard ImageNet size)

        # Training hyperparameters
        self.lr = 0.0001  # Initial learning rate
        self.steps = '20, 40, 60, 80'  # Epochs at which to decay learning rate (comma-separated)

        # Loss weights - control the contribution of different loss components
        self.beta_map = 0.01  # Weight for visual-text alignment loss
        self.beta_con = 0.01  # Weight for mapping consistency loss (preserves semantic relationships)
        self.beta_rank = 1  # Weight for ranking loss (main loss for ZSL)
        self.neg_penalty = 0.20  # Margin penalty for ranking loss (how much higher correct labels should rank)

        # Loss flags - control which loss components are used
        self.wo_con = False  # If True, disable consistency regularizer loss
        self.wo_map = False  # If True, disable alignment loss

        # Embeddings - path to pre-computed text embeddings for disease classes
        self.textual_embeddings = 'embeddings/nih_chest_xray_biobert.npy'  # BioBERT embeddings for class names

# Create args object - this will be used throughout the notebook
args = Args()

# %% [markdown]
# ## Dataset Class (from dataset.py)

# %%
class NIHChestXray(torch.utils.data.Dataset):
    """
    PyTorch Dataset class for NIH Chest X-ray dataset.
    Handles loading images and labels, with support for zero-shot learning splits.
    """
    def __init__ (self, args, pathDatasetFile, transform, classes_to_load='seen', exclude_all=True):
        """
        Args:
            args: Configuration object with dataset paths and settings
            pathDatasetFile: Path to text file containing list of image filenames for this split
            transform: PyTorch transforms to apply to images
            classes_to_load: 'seen', 'unseen', or 'all' - which classes to include
            exclude_all: If True, exclude images that have both seen and unseen classes
        """
        # Initialize empty lists for image paths and labels
        self.listImagePaths = []
        self.listImageLabels = []
        self.transform = transform  # Image transformations (resize, crop, normalize, etc.)
        self.num_classes = args.num_classes  # Total number of disease classes (14)

        # Store paths and arguments
        self._data_path = args.data_root  # Root directory of the dataset
        self.args = args
        self.split_path = pathDatasetFile  # Path to split file (train.txt, val.txt, test.txt)

        # Define all disease classes in the dataset
        self.CLASSES = [ 'Atelectasis', 'Cardiomegaly', 'Effusion', 'Infiltration', 'Mass', 'Nodule', 'Pneumonia',
                'Pneumothorax', 'Consolidation', 'Edema', 'Emphysema', 'Fibrosis', 'Pleural_Thickening', 'Hernia']

        # Zero-shot learning split: unseen classes (not seen during training)
        self.unseen_classes = ['Edema', 'Pneumonia', 'Emphysema', 'Fibrosis']

        # Zero-shot learning split: seen classes (available during training)
        self.seen_classes = [ 'Atelectasis', 'Effusion', 'Infiltration', 'Mass', 'Nodule',
                'Pneumothorax', 'Consolidation', 'Cardiomegaly', 'Pleural_Thickening', 'Hernia']

        # Create mapping from class name to class ID (0-13, excluding 'No Finding')
        self._class_ids = {v: i for i, v in enumerate(self.CLASSES) if v != 'No Finding'}

        # Convert class names to class IDs for seen and unseen classes
        self.seen_class_ids = [self._class_ids[label] for label in self.seen_classes]
        self.unseen_class_ids = [self._class_ids[label] for label in self.unseen_classes]

        # Store filtering options
        self.classes_to_load = classes_to_load  # Which classes to include in this dataset
        self.exclude_all = exclude_all  # Whether to exclude mixed-label images

        # Build the dataset index (loads all image paths and labels)
        self._construct_index()

    def _construct_index(self):
        """
        Build the dataset index by:
        1. Finding all image files in the dataset
        2. Reading the split file to get which images belong to this split
        3. Reading the CSV file to get labels for each image
        4. Filtering images based on class selection criteria
        """
        max_labels = 0  # Track maximum number of labels per image

        # Find all PNG images in the dataset directory structure
        paths = glob.glob(f'{self._data_path}/images/*.png')
        # Create mapping from filename to full path for quick lookup
        self.names_to_path = {path.split('/')[-1]: path for path in paths}

        # Read the data entry CSV file that contains image labels
        data_entry_file = 'Data_Entry_2017_v2020.csv'
        print(f'data partition path: {self.split_path}')

        # Read the split file (train.txt, val.txt, or test.txt) to get image filenames
        with open(self.split_path, 'r') as f:
            file_names = f.readlines()

        # Extract just the filename from each line (handles paths like "images/00000001_000.png")
        split_file_names = np.array([file_name.strip().split(' ')[0].split('/')[-1] for file_name in file_names])

        # Read the main CSV file containing all image labels
        df = pd.read_csv(f'{self._data_path}/{data_entry_file}')
        image_index = df.iloc[:, 0].values  # First column: image filenames

        # Find intersection: which images from the split file are in the CSV
        _, split_index, _ = np.intersect1d(image_index, split_file_names, return_indices=True)

        # Get labels for images in this split (second column of CSV contains labels)
        labels = df.iloc[:, 1].values
        labels = np.array(labels)[split_index]  # Filter labels to only this split

        # Labels are pipe-separated (e.g., "Atelectasis|Effusion"), split them into lists
        labels = [label.split('|') for label in labels]

        # Filter image index to only this split
        image_index = image_index[split_index]

        # Construct the image database: list of dictionaries with image path and labels
        self._imdb = []
        self.class_ids_loaded = []  # Track which class IDs appear in this dataset

        for index in range(len(split_index)):
            # Skip images with only "No Finding" label (no diseases)
            if len(labels[index]) == 1 and labels[index][0] == 'No Finding':
                continue

            # Apply class filtering (seen/unseen/all)
            if self._should_load_image(labels[index]) is False:
                continue

            # Convert class names to class IDs
            class_ids = [self._class_ids[label] for label in labels[index]]
            self.class_ids_loaded += class_ids  # Track all class IDs we've seen

            # Add image to database
            try:
              self._imdb.append({
                  'im_path': self.names_to_path[image_index[index]],  # Full path to image
                  'labels': class_ids,  # List of class IDs for this image
              })
              max_labels = max(max_labels, len(class_ids))  # Update max labels per image
            except:
              # Ignore in case the names are missing (didn't unpack all images) for testing...
              pass

        # Get unique class IDs that appear in this dataset
        self.class_ids_loaded = np.unique(np.array(self.class_ids_loaded))

        # Print dataset statistics
        print(f'Number of images: {len(self._imdb)}')
        print(f'Number of max labels per image: {max_labels}')
        print(f'Number of classes: {len(self.class_ids_loaded)}')


    def _should_load_image(self, labels):
        """
        Determine if an image should be included based on its labels and filtering criteria.

        Args:
            labels: List of class names for an image

        Returns:
            True if image should be loaded, False otherwise
        """
        # Determine which classes we're interested in based on classes_to_load
        selected_class_labels = self.CLASSES  # Default: all classes
        if self.classes_to_load == 'seen':
            selected_class_labels = self.seen_classes  # Only seen classes
        elif self.classes_to_load == 'unseen':
            selected_class_labels = self.unseen_classes  # Only unseen classes
        elif self.classes_to_load == 'all':
            return True  # Load all images regardless of labels

        # Count how many of this image's labels are in the selected set
        count = 0
        for label in labels:
            if label in selected_class_labels:
                count += 1

        if count == len(labels):
            # All labels are from the selected subset - include this image
            return True
        elif count == 0:
            # None of the labels are in the selected subset - exclude this image
            return False
        else:
            # Some labels are in the selected subset (mixed case)
            if self.exclude_all is True:
                return False  # Exclude images with mixed seen/unseen labels
            else:
                return True  # Include images with mixed labels


    def __getitem__(self, index):
        """
        Get a single image and its labels.

        Args:
            index: Index of the image to retrieve

        Returns:
            img: Transformed image tensor
            imageLabel: One-hot encoded label vector (14 classes)
        """
        # Get the image path from the database
        imagePath = self._imdb[index]['im_path']

        # Load and convert image to RGB (ensures 3 channels)
        imageData = Image.open(imagePath).convert('RGB')

        # Get class IDs for this image and convert to tensor
        labels = torch.tensor(self._imdb[index]['labels'])

        # Convert class IDs to one-hot encoding
        # First add a batch dimension, then create one-hot vector
        labels = labels.unsqueeze(0)  # Shape: [1, num_labels]
        # Create zero vector and scatter 1s at label positions
        imageLabel = torch.zeros(labels.size(0), self.num_classes).scatter_(1, labels, 1.).squeeze()
        # Result: [14] tensor with 1s at positions corresponding to diseases present

        # Apply transforms (resize, crop, normalize, etc.)
        img = self.transform(imageData)

        return img, imageLabel

    def __len__(self):
        """Return the number of images in the dataset."""
        return len(self._imdb)

# %% [markdown]
# ## Loss Functions (from loss.py)

# %%
class RankingLoss(nn.Module):
    """
    Ranking Loss for Zero-Shot Learning.
    Ensures that correct class similarities are higher than incorrect ones by a margin.
    This is the main loss function for training the ZSL model.
    """
    def __init__(self, neg_penalty=0.03):
        """
        Args:
            neg_penalty: Margin penalty - how much higher correct labels should rank than incorrect ones
        """
        super(RankingLoss, self).__init__()
        self.neg_penalty = neg_penalty

    def forward(self, ranks, labels, class_ids_loaded, device):
        """
        Compute ranking loss.
        For each image, ensures that similarity scores for present diseases are higher
        than scores for absent diseases by at least neg_penalty.

        Args:
            ranks: [batch_size, num_classes] similarity scores between images and class embeddings
            labels: [batch_size, num_classes] binary labels (1 = present, 0 = absent)
            class_ids_loaded: List of class IDs that are available in this dataset
            device: Device to place tensors on

        Returns:
            Ranking loss (scalar)
        """
        # Filter to only classes that are loaded in this dataset
        labels = labels[:, class_ids_loaded]  # [batch_size, num_loaded_classes]
        ranks_loaded = ranks[:, class_ids_loaded]  # [batch_size, num_loaded_classes]

        # Create negative labels (1 - labels): 1 where disease is absent, 0 where present
        neg_labels = 1 + (labels * -1)  # Invert labels

        loss_rank = torch.zeros(1).to(device)

        # Process each image in the batch
        for i in range(len(labels)):
            # Get similarity scores for present diseases (correct)
            correct = ranks_loaded[i, labels[i]==1]  # [num_correct]
            # Get similarity scores for absent diseases (wrong)
            wrong = ranks_loaded[i, neg_labels[i]==1]  # [num_wrong]

            # Create pairwise comparisons: for each correct class, compare with all wrong classes
            # Expand dimensions to create a matrix: [num_correct, num_wrong]
            correct = correct.reshape((-1, 1)).repeat((1, len(wrong)))  # [num_correct, num_wrong]
            wrong = wrong.repeat(len(correct)).reshape(len(correct), -1)  # [num_correct, num_wrong]

            # Compute penalty: (neg_penalty + wrong_score) - correct_score
            # We want correct_score > wrong_score + neg_penalty
            # So penalty = wrong_score + neg_penalty - correct_score should be <= 0
            image_level_penalty = ((self.neg_penalty + wrong) - correct)
            image_level_penalty[image_level_penalty < 0] = 0  # Only penalize when margin is violated

            # Sum all violations for this image
            loss_rank += image_level_penalty.sum()

        # Average over batch
        loss_rank /= len(labels)
        return loss_rank

class CosineLoss(nn.Module):
    """
    Cosine Similarity Loss.
    Measures the cosine similarity between two embeddings.
    Used to align visual and textual embeddings in the same space.
    """
    def forward(self, t_emb, v_emb):
        """
        Compute cosine similarity loss between text and visual embeddings.

        Args:
            t_emb: Text embeddings [batch_size, embedding_dim]
            v_emb: Visual embeddings [batch_size, embedding_dim]

        Returns:
            Cosine loss (1 - mean cosine similarity), ranges from 0 to 2
        """
        # Normalize embeddings to unit vectors
        a_norm = v_emb / v_emb.norm(dim=1)[:, None]  # [batch_size, embedding_dim]
        b_norm = t_emb / t_emb.norm(dim=1)[:, None]  # [batch_size, embedding_dim]

        # Compute cosine similarity matrix: [batch_size, batch_size]
        # Diagonal elements are similarities between corresponding pairs
        similarity_matrix = torch.mm(a_norm, b_norm.t())  # [batch_size, batch_size]
        diagonal_similarities = torch.diagonal(similarity_matrix, 0)  # [batch_size] - matching pairs

        # Loss is 1 minus mean cosine similarity (we want high similarity = low loss)
        loss = 1 - torch.mean(diagonal_similarities)
        return loss

# %% [markdown]
# ## Plotting Functions (from plots.py)

# %%
def plot_array(array, disc='loss'):
    """
    Simple plotting function to visualize training metrics over time.

    Args:
        array: List or array of values to plot (e.g., validation losses per epoch)
        disc: Description/label for the y-axis (e.g., 'loss', 'accuracy')
    """
    plt.plot(array)  # Plot the values
    plt.ylabel(disc)  # Label the y-axis
    plt.savefig(f'{disc}.pdf')  # Save as PDF
    plt.close()  # Close the figure to free memory

# %% [markdown]
# ## ZSL Model (from zsl_models.py)

# %%
class ZSLNet(nn.Module):
    """
    Zero-Shot Learning Network for Chest X-ray Disease Classification.

    This model combines:
    1. A vision backbone (e.g., DenseNet) to extract visual features from images
    2. Text embeddings (BioBERT) for disease class descriptions
    3. Mapping networks to project both modalities into a shared embedding space
    4. Similarity-based classification using cosine similarity between visual and text embeddings
    """
    def __init__(self, args, textual_embeddings=None, device='cpu'):
        """
        Initialize the ZSL network.

        Args:
            args: Configuration object with model hyperparameters
            textual_embeddings: Pre-computed text embeddings for disease classes [num_classes, embedding_dim]
            device: Device to run the model on ('cpu' or 'cuda')
        """
        super(ZSLNet, self).__init__()
        self.args = args
        self.device = device

        # Load pre-trained vision backbone (e.g., DenseNet121 with ImageNet weights)
        self.vision_backbone = getattr(torchvision.models, self.args.vision_backbone)(pretrained=self.args.pretrained)

        # Remove the classification layer from the vision backbone
        # We want to extract features, not classify into ImageNet classes
        classifiers = ['classifier', 'fc']  # Different models use different names
        for classifier in classifiers:
            cls_layer = getattr(self.vision_backbone, classifier, None)
            if cls_layer is None:
                continue  # Try next classifier name
            # Get the input dimension of the classifier (this is our visual feature dimension)
            d_visual = cls_layer.in_features
            # Replace classifier with identity function (pass-through)
            setattr(self.vision_backbone, classifier, nn.Identity())
            break  # Found and replaced, exit loop

        # Optional: Load a pre-trained encoder (currently disabled)
        pretrained_encoder = False
        if pretrained_encoder:
            self.vision_backbone.classifier = nn.Identity()
            path = 'checkpoints/bce_only_imagenet/last_epoch_checkpoint.pth.tar'
            self.classifier = nn.Sequential(nn.Linear(d_visual, self.args.num_classes), nn.Sigmoid())
            checkpoint = torch.load(path, weights_only=False)
            self.load_state_dict(checkpoint['state_dict'])
            # Freeze vision backbone parameters
            for p in self.vision_backbone.parameters():
                p.requires_grad = False

        # Two training modes: BCE-only (standard classification) or ZSL (ranking-based)
        if self.args.bce_only:
            # Standard binary cross-entropy classification
            self.bce_loss = torch.nn.BCELoss(size_average=True)
            self.classifier = nn.Sequential(
                nn.Linear(d_visual, self.args.num_classes),
                nn.Sigmoid()  # Multi-label classification
            )
        else:
            # Zero-shot learning mode: use ranking loss and embedding alignment
            self.emb_loss = CosineLoss()  # Align visual and text embeddings
            self.ranking_loss = RankingLoss(neg_penalty=self.args.neg_penalty)  # Main ZSL loss

            # Store and convert text embeddings to tensor
            self.textual_embeddings = textual_embeddings
            d_textual = self.textual_embeddings.shape[-1]  # Dimension of text embeddings
            self.textual_embeddings = torch.from_numpy(self.textual_embeddings).to(self.device)

            # Visual feature mapping network: projects visual features to shared space
            # Architecture: d_visual -> 512 -> 256 -> 128
            self.fc_v = nn.Sequential(
                nn.Linear(d_visual, 512),
                nn.ReLU(),
                nn.Linear(512, 256),
                nn.ReLU(),
                nn.Linear(256, 128),  # Final visual embedding dimension
            )

            # Text feature mapping network: projects text embeddings to shared space
            # Architecture: d_textual -> 512 -> 256 -> 128
            self.fc_t = nn.Sequential(
                nn.Linear(d_textual, 512),
                nn.ReLU(),
                nn.Linear(512, 256),
                nn.ReLU(),
                nn.Linear(256, 128)  # Final text embedding dimension (matches visual)
            )


    def forward(self, x, labels=None, epoch=0, n_crops=0, bs=16):
        """
        Forward pass through the network.

        Args:
            x: Input images [batch_size, channels, height, width] or [batch_size*n_crops, ...] for test-time augmentation
            labels: Ground truth labels [batch_size, num_classes] (optional, for training)
            epoch: Current training epoch (used to enable/disable certain losses)
            n_crops: Number of crops per image (for test-time augmentation, 0 during training)
            bs: Batch size (needed when n_crops > 0 to reshape outputs)

        Returns:
            If bce_only: (predictions, loss, loss_string)
            Otherwise: (similarity_scores, total_loss)
        """
        if self.args.bce_only:
            return self.forward_bce_only(x, labels=labels, n_crops=n_crops, bs=bs)
        else:
            return self.forward_ranking(x, labels=labels, epoch=epoch, n_crops=n_crops, bs=bs)

    def forward_bce_only(self, x, labels=None, n_crops=0, bs=16):
        """
        Forward pass for BCE-only mode (standard multi-label classification).
        """
        lossvalue_bce = torch.zeros(1).to(self.device)

        # Extract visual features using the backbone
        visual_feats = self.vision_backbone(x)  # [batch_size, d_visual]
        # Classify directly to disease classes
        preds = self.classifier(visual_feats)  # [batch_size, num_classes]

        # Compute binary cross-entropy loss if labels provided
        if labels is not None:
            lossvalue_bce = self.bce_loss(preds, labels)

        return preds, lossvalue_bce, f'bce:\t {lossvalue_bce.item():0.4f}'


    def forward_ranking(self, x, labels=None, epoch=0, n_crops=0, bs=16):
        """
        Forward pass for ZSL ranking-based mode.
        Projects visual and text features to shared space and computes similarity scores.
        """
        # Initialize loss components
        loss_rank = torch.zeros(1).to(self.device)  # Main ranking loss
        loss_allignment_cos = torch.zeros(1).to(self.device)  # Visual-text alignment loss
        loss_mapping_consistency = torch.zeros(1).to(self.device)  # Consistency regularizer

        # Extract visual features and project to shared embedding space
        visual_feats = self.vision_backbone(x)  # [batch_size, d_visual]
        visual_feats = self.fc_v(visual_feats)  # [batch_size, 128]

        # Project text embeddings to shared space
        text_feats = self.fc_t(self.textual_embeddings)  # [num_classes, 128]

        # Mapping consistency loss: preserve semantic relationships in text embeddings
        # Ensures that the mapped text embeddings maintain the same similarity structure as original
        if not self.args.wo_con and epoch >= 0:
            # Compute similarity matrix of mapped text embeddings
            text_mapped_sim = self.sim_score(text_feats, text_feats.detach())  # [num_classes, num_classes]
            # Compute similarity matrix of original text embeddings
            text_orig_sim = self.sim_score(self.textual_embeddings, self.textual_embeddings)  # [num_classes, num_classes]
            # Loss: difference between similarity matrices (should be small)
            loss_mapping_consistency = torch.abs(text_orig_sim - text_mapped_sim).mean()

        # Visual-text alignment loss: align visual features with corresponding text features
        # Currently disabled (multiplied by 0.0) but code is kept for potential use
        if labels is not None:
            mapped_visual, mapped_text = self.map_visual_text(visual_feats, labels, text_feats)
            if mapped_visual is not None and not self.args.wo_map and epoch >= 0:
                # Compute cosine loss between visual features and average text features of present classes
                loss_allignment_cos = self.emb_loss(mapped_text, mapped_visual)

        # Compute similarity scores between visual features and all class text embeddings
        ranks = self.sim_score(visual_feats, text_feats)  # [batch_size, num_classes]

        # Handle test-time augmentation: average predictions across multiple crops
        if n_crops > 0:
            # Reshape: [batch_size*n_crops, num_classes] -> [batch_size, n_crops, num_classes]
            ranks = ranks.view(bs, n_crops, -1).mean(1)  # Average over crops: [batch_size, num_classes]

        # Compute ranking loss if labels provided (training mode)
        if labels is not None:
            loss_rank = self.ranking_loss(ranks, labels, self.class_ids_loaded, self.device)

        # Weight and combine loss components
        loss_allignment_cos = (self.args.beta_map * loss_allignment_cos)
        loss_rank = (self.args.beta_rank * loss_rank)  # Main loss
        loss_mapping_consistency = (self.args.beta_con * loss_mapping_consistency)  # Regularizer

        # Total loss (alignment loss disabled with 0.0 multiplier)
        losses = loss_rank + loss_mapping_consistency + loss_allignment_cos

        return ranks, losses

    def sim_score(self, a, b):
        """
        Compute cosine similarity matrix between two sets of embeddings.

        Args:
            a: First set of embeddings [N, embedding_dim]
            b: Second set of embeddings [M, embedding_dim]

        Returns:
            Similarity matrix [N, M] where element (i,j) is cosine similarity between a[i] and b[j]
        """
        # Normalize to unit vectors
        a_norm = a / a.norm(dim=1)[:, None]  # [N, embedding_dim]
        b_norm = b / (1e-6 + b.norm(dim=1))[:, None]  # [M, embedding_dim] (small epsilon for numerical stability)

        # Compute cosine similarity: dot product of normalized vectors
        score = torch.mm(a_norm, b_norm.t())  # [N, M]
        return score

    def map_visual_text(self, visual_feats, labels, labels_embd):
        """
        Map visual features to text embeddings for alignment loss.
        For each image, compute the average text embedding of its present classes.

        Args:
            visual_feats: Visual features [batch_size, embedding_dim]
            labels: Binary labels [batch_size, num_classes]
            labels_embd: Text embeddings for all classes [num_classes, embedding_dim]

        Returns:
            mapped_visual: Visual features (detached)
            mapped_labels_embd: Average text embeddings for present classes in each image [batch_size, embedding_dim]
        """
        mapped_labels_embd = []

        # Process each image in the batch
        for i in range(0, labels.shape[0]):
            # Get text embeddings for classes present in this image
            # labels[i]==1 gives boolean mask, use it to index into labels_embd
            class_embd = labels_embd[labels[i]==1].mean(dim=0)[None, :]  # [1, embedding_dim]
            mapped_labels_embd.append(class_embd)

        # Concatenate all averaged embeddings
        mapped_labels_embd = torch.cat(mapped_labels_embd)  # [batch_size, embedding_dim]

        # Return detached tensors (gradients won't flow through these in alignment loss)
        return visual_feats.detach(), mapped_labels_embd.detach()

# %% [markdown]
# ## Trainer Class (from ChexnetTrainer.py)

# %%
class ChexnetTrainer(object):
    """
    Main training class that orchestrates the entire training and evaluation process.
    Handles data loading, model training, validation, testing, and checkpoint management.
    """
    def __init__(self, args):
        """
        Initialize the trainer with model, optimizer, datasets, and training state.

        Args:
            args: Configuration object with all hyperparameters and paths
        """
        self.args = args

        # Set device (GPU if available, else CPU)
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Load pre-computed text embeddings for disease classes
        self.textual_embeddings = np.load(args.textual_embeddings)

        # Initialize the model and move to device
        self.model = ZSLNet(self.args, self.textual_embeddings, self.device).to(self.device)

        # Initialize optimizer (Adam with default hyperparameters)
        self.optimizer = optim.Adam(
            self.model.parameters(),
            lr=self.args.lr,
            betas=(0.9, 0.999),
            eps=1e-08,
            weight_decay=1e-5
        )

        # Learning rate scheduler: reduces LR when validation loss plateaus
        self.scheduler = ReduceLROnPlateau(self.optimizer, factor=0.1, patience=5, mode='min')

        # Loss function (for BCE-only mode, though ZSL mode uses ranking loss)
        self.loss = torch.nn.BCELoss(size_average=True)

        # Training state tracking
        self.auroc_min_loss = 0.0  # AUROC achieved at minimum validation loss
        self.start_epoch = 1  # Starting epoch (1 for new training, >1 if resuming)
        self.lossMIN = float('inf')  # Minimum validation loss seen so far
        self.max_auroc_mean = float('-inf')  # Maximum mean AUROC seen so far
        self.best_epoch = 1  # Epoch with best AUROC

        # Track validation losses for plotting
        self.val_losses = []

        # Early stopping: track epochs since last improvement
        self.epochs_since_improvement = 0  # Counter for early stopping

        # Print model and training configuration
        # print(self.model)
        # print(self.optimizer)
        # print(self.scheduler)
        # print(self.loss)
        print(f'\n\nloaded imagenet weights {self.args.pretrained}\n\n\n')

        # Load checkpoints if specified (resume training or load weights)
        self.resume_from()  # Resume training from checkpoint (includes optimizer state)
        self.load_from()  # Load weights from checkpoint (weights only)

        # Initialize datasets and data loaders
        self.init_dataset()

        # Parse learning rate decay steps
        self.steps = [int(step) for step in self.args.steps.split(',')]

        # Time tracking for ETA calculation
        self.time_start = time.time()
        self.time_end = time.time()

        # Flag to determine if we should run test set evaluation
        self.should_test = False

        # Store class IDs that are loaded in the training dataset
        self.model.class_ids_loaded = self.train_dl.dataset.class_ids_loaded


    def __call__(self):
        self.train()

    def step_lr(self, epoch):
        step = self.steps[0]
        for index, s in enumerate(self.steps):
            if epoch < s:
                break
            else:
                step = s

        lr = self.args.lr * (0.1 ** (epoch // step))
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr

    def load_from(self):
        if self.args.load_from is not None:
            checkpoint = torch.load(self.args.load_from, weights_only=False)
            self.model.load_state_dict(checkpoint['state_dict'])
            print(f'loaded checkpoint from {self.args.load_from}')

    def resume_from(self):
        if self.args.resume_from is not None:
            checkpoint = torch.load(self.args.resume_from, weights_only=False)
            self.model.load_state_dict(checkpoint['state_dict'])
            self.optimizer.load_state_dict(checkpoint['optimizer'])
            self.start_epoch = checkpoint['epoch'] + 1
            self.lossMIN = checkpoint['lossMIN']
            self.max_auroc_mean = checkpoint['max_auroc_mean']
            print(f'resuming training from epoch {self.start_epoch}')

    def save_checkpoint(self, prefix='best'):
        path = f'{self.args.save_dir}/{prefix}_checkpoint.pth.tar'
        torch.save(
            {
            'epoch': self.epoch,
            'state_dict': self.model.state_dict(),
            'max_auroc_mean': self.max_auroc_mean,
            'optimizer' : self.optimizer.state_dict(),
            'lossMIN' : self.lossMIN
            }, path)
        print(f"saving {prefix} checkpoint")
    def init_dataset(self):
        normalize = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

        train_transforms = []
        train_transforms.append(transforms.RandomResizedCrop(self.args.crop))
        train_transforms.append(transforms.RandomHorizontalFlip())
        train_transforms.append(transforms.ToTensor())
        train_transforms.append(normalize)

        datasetTrain = NIHChestXray(self.args, self.args.train_file, transform=transforms.Compose(train_transforms))

        self.train_dl = DataLoader(dataset=datasetTrain, batch_size=self.args.batch_size, shuffle=True,  num_workers=4, pin_memory=True)


        test_transforms = []
        test_transforms.append(transforms.Resize(self.args.resize))
        test_transforms.append(transforms.TenCrop(self.args.crop))
        test_transforms.append(transforms.Lambda(lambda crops: torch.stack([transforms.ToTensor()(crop) for crop in crops])))
        test_transforms.append(transforms.Lambda(lambda crops: torch.stack([normalize(crop) for crop in crops])))


        datasetVal =   NIHChestXray(self.args, self.args.val_file, transform=transforms.Compose(test_transforms))
        self.val_dl = DataLoader(dataset=datasetVal, batch_size=self.args.batch_size*10, shuffle=False, num_workers=4, pin_memory=True)

        datasetTest = NIHChestXray(self.args, self.args.test_file, transform=transforms.Compose(test_transforms), classes_to_load='all')
        self.test_dl = DataLoader(dataset=datasetTest, batch_size=self.args.batch_size*3, num_workers=8, shuffle=False, pin_memory=True)
        print(datasetTest.CLASSES)


    def train(self):
        """
        Main training loop.
        For each epoch:
        1. Train on training set
        2. Validate on validation set
        3. Save checkpoints if performance improves
        4. Test on test set if new best model found
        5. Update learning rate scheduler
        """
        for self.epoch in range(self.start_epoch, self.args.epochs):
            # Train for one epoch
            self.epochTrain()

            # Validate on validation set
            lossVal, val_ind_auroc = self.epochVal()
            val_ind_auroc = np.array(val_ind_auroc)

            # Compute mean AUROC across all classes
            aurocMean = val_ind_auroc.mean()

            # Always save the last epoch checkpoint
            self.save_checkpoint(prefix=f'last_epoch')
            self.should_test = False  # Reset test flag

            # Check if this is the best model by AUROC
            if aurocMean > self.max_auroc_mean:
                self.max_auroc_mean = aurocMean
                self.save_checkpoint(prefix='best_auroc')  # Save best AUROC model
                self.best_epoch = self.epoch
                self.should_test = True  # Test this model
                self.epochs_since_improvement = 0  # Reset counter on improvement

            else:
                # No improvement in AUROC
                self.epochs_since_improvement += 1

            # Early stopping check
            if self.args.early_stopping_patience is not None and self.epochs_since_improvement >= self.args.early_stopping_patience:
                print(f'\nEarly stopping triggered: No improvement in max_auroc_mean for {self.args.early_stopping_patience} epochs.')
                print(f'Best AUROC was {self.max_auroc_mean:.4f} at epoch {self.best_epoch}')
                break

            # Check if this is the model with minimum validation loss
            if lossVal < self.lossMIN:
                self.lossMIN = lossVal
                self.auroc_min_loss = aurocMean  # Track AUROC at min loss
                self.save_checkpoint(prefix='min_loss')  # Save min loss model
                self.should_test = True  # Test this model

            # Print validation AUROC results
            self.print_auroc(val_ind_auroc, self.val_dl.dataset.class_ids_loaded, prefix='val')

            # If we have a new best model, evaluate on test set
            if self.should_test is True:
                test_ind_auroc = self.test()
                test_ind_auroc = np.array(test_ind_auroc)

                # Write results to file
                self.write_results(val_ind_auroc, self.val_dl.dataset.class_ids_loaded,
                                 prefix=f'\n\nepoch {self.epoch}\nval', mode='a')
                # Write test results for seen classes (classes seen during training)
                self.write_results(test_ind_auroc[self.test_dl.dataset.seen_class_ids],
                                 self.test_dl.dataset.seen_class_ids, prefix='\ntest_seen', mode='a')
                # Write test results for unseen classes (zero-shot learning evaluation)
                self.write_results(test_ind_auroc[self.test_dl.dataset.unseen_class_ids],
                                 self.test_dl.dataset.unseen_class_ids, prefix='\ntest_unseen', mode='a')

                # Print test results
                self.print_auroc(test_ind_auroc[self.test_dl.dataset.seen_class_ids],
                               self.test_dl.dataset.seen_class_ids, prefix='\ntest_seen')
                self.print_auroc(test_ind_auroc[self.test_dl.dataset.unseen_class_ids],
                               self.test_dl.dataset.unseen_class_ids, prefix='\ntest_unseen')

            # Plot validation loss curve
            plot_array(self.val_losses, f'{self.args.save_dir}/val_loss')

            # Print training summary
            print(f'best epoch {self.best_epoch} best auroc {self.max_auroc_mean} loss {lossVal:.6f} auroc at min loss {self.auroc_min_loss:0.4f}')

            # Update learning rate based on validation loss
            self.scheduler.step(lossVal)


    def get_eta(self, epoch, iter):
        self.time_end = time.time()
        delta = self.time_end - self.time_start
        delta = delta * (len(self.train_dl) * (self.args.epochs - epoch) - iter)
        sec = timedelta(seconds=int(delta))
        d = (datetime(1,1,1) + sec)
        eta = f"{d.day-1} Days {d.hour}:{d.minute}:{d.second}"
        self.time_start = time.time()

        return eta



    def epochTrain(self):
        """
        Train the model for one epoch on the training set.
        Processes batches, computes loss, backpropagates, and updates weights.
        """
        self.model.train()  # Set model to training mode (enables dropout, batch norm updates, etc.)
        epoch_loss = 0

        # Iterate over training batches
        for batchID, (inputs, target) in enumerate(self.train_dl):
            # Move data to device (GPU or CPU)
            target = target.to(self.device)  # Labels: [batch_size, num_classes]
            inputs = inputs.to(self.device)  # Images: [batch_size, channels, height, width]

            # Forward pass: compute predictions and loss
            output, loss = self.model(inputs, target, self.epoch)

            # Backward pass: compute gradients
            self.optimizer.zero_grad()  # Clear gradients from previous iteration
            loss.backward()  # Compute gradients
            self.optimizer.step()  # Update model weights

            # Calculate estimated time to completion
            eta = self.get_eta(self.epoch, batchID)
            epoch_loss += loss.item()

            # Print progress every 10 batches
            if batchID % 10 == 9:
                print(f" epoch [{self.epoch:04d} / {self.args.epochs:04d}] eta: {eta:<20} "
                      f"[{batchID:04}/{len(self.train_dl)}] lr: \t{self.optimizer.param_groups[0]['lr']:0.4E} "
                      f"loss: \t{epoch_loss/batchID:0.5f}")



    def epochVal(self):
        """
        Validate the model on the validation set.
        Uses test-time augmentation (10 crops) and computes AUROC for each class.

        Returns:
            lossVal: Average validation loss
            aurocIndividual: List of AUROC scores for each class
        """
        self.model.eval()  # Set model to evaluation mode (disables dropout, batch norm uses running stats)

        lossVal = 0

        # Accumulate predictions and ground truth for all batches
        outGT = torch.FloatTensor().to(self.device)  # Ground truth labels
        outPRED = torch.FloatTensor().to(self.device)  # Model predictions

        # Iterate over validation batches (with progress bar)
        for i, (inputs, target) in enumerate(tqdm(self.val_dl)):
            with torch.no_grad():  # Disable gradient computation for efficiency
                target = target.to(self.device)
                inputs = inputs.to(self.device)

                # Handle test-time augmentation: inputs have shape [batch_size, n_crops, channels, height, width]
                # where n_crops=10 (TenCrop augmentation)
                varTarget = torch.autograd.Variable(target)  # Legacy Variable wrapper
                bs, n_crops, c, h, w = inputs.size()  # Extract dimensions

                # Reshape to process all crops: [batch_size*n_crops, channels, height, width]
                varInput = torch.autograd.Variable(inputs.view(-1, c, h, w).to(self.device))

                # Forward pass: model will average predictions across crops
                varOutput, losstensor = self.model(varInput, varTarget, n_crops=n_crops, bs=bs)

                # Accumulate predictions and ground truth
                outPRED = torch.cat((outPRED, varOutput), 0)  # [total_samples, num_classes]
                outGT = torch.cat((outGT, target), 0)  # [total_samples, num_classes]

                # Accumulate loss
                lossVal += losstensor.item()

                # Free memory
                del varOutput, varTarget, varInput, target, inputs

        # Compute average loss
        lossVal = lossVal / len(self.val_dl)

        # Compute AUROC for each class
        aurocIndividual = self.computeAUROC(outGT, outPRED, self.val_dl.dataset.class_ids_loaded)

        # Track validation loss for plotting
        self.val_losses.append(lossVal)

        return lossVal, aurocIndividual



    def test(self):
        """
        Test the model on the test set.
        Similar to validation but on the full test set (includes both seen and unseen classes).

        Returns:
            aurocIndividual: List of AUROC scores for each class in the test set
        """
        # Enable CUDA benchmarking for faster inference (optimizes convolution operations)
        cudnn.benchmark = True

        # Accumulate predictions and ground truth
        outGT = torch.FloatTensor().to(self.device)
        outPRED = torch.FloatTensor().to(self.device)

        self.model.eval()  # Set to evaluation mode

        # Iterate over test batches
        for i, (inputs, target) in enumerate(tqdm(self.test_dl)):
            with torch.no_grad():  # No gradients needed for testing
                target = target.to(self.device)
                outGT = torch.cat((outGT, target), 0)  # Accumulate ground truth

                # Handle test-time augmentation (10 crops)
                bs, n_crops, c, h, w = inputs.size()

                # Reshape to process all crops
                varInput = torch.autograd.Variable(inputs.view(-1, c, h, w).to(self.device))

                # Forward pass (no labels needed, just predictions)
                out, _ = self.model(varInput, n_crops=n_crops, bs=bs)

                # Accumulate predictions
                outPRED = torch.cat((outPRED, out.data), 0)

        # Compute AUROC for each class
        aurocIndividual = self.computeAUROC(outGT, outPRED, self.test_dl.dataset.class_ids_loaded)

        # Compute mean AUROC (for reference, not returned)
        aurocMean = np.array(aurocIndividual).mean()

        return aurocIndividual

    def computeAUROC(self, dataGT, dataPRED, class_ids):
        """
        Compute Area Under ROC Curve (AUROC) for each class.

        Args:
            dataGT: Ground truth labels [num_samples, num_classes]
            dataPRED: Predicted scores [num_samples, num_classes]
            class_ids: List of class IDs to compute AUROC for

        Returns:
            List of AUROC scores, one for each class in class_ids
        """
        outAUROC = []

        # Convert to numpy for sklearn
        datanpGT = dataGT.cpu().numpy()  # Ground truth: [num_samples, num_classes]
        datanpPRED = dataPRED.cpu().numpy()  # Predictions: [num_samples, num_classes]

        # Compute AUROC for each class
        for i in class_ids:
            # AUROC for binary classification: true labels vs predicted scores for class i
            auroc = roc_auc_score(datanpGT[:, i], datanpPRED[:, i])
            outAUROC.append(auroc)

        return outAUROC

    def write_results(self, aurocIndividual, class_ids, prefix='val', mode='a'):

        with open(f"{self.args.save_dir}/results.txt", mode) as results_file:

            aurocMean = aurocIndividual.mean()

            results_file.write(f'{prefix} AUROC mean {aurocMean:0.4f}\n')
            for i, class_id in enumerate(class_ids):
                results_file.write(f'{self.val_dl.dataset.CLASSES[class_id]} {aurocIndividual[i]:0.4f}\n')

    def print_auroc(self, aurocIndividual, class_ids, prefix='val'):
        aurocMean = aurocIndividual.mean()

        print (f'{prefix} AUROC mean {aurocMean:0.4f}')

        for i, class_id in enumerate(class_ids):
            print (f'{self.val_dl.dataset.CLASSES[class_id]} {aurocIndividual[i]:0.4f}')

# %% [markdown]
# ## Training and Testing Functions
#
# Define functions for training and testing. Run the cells below to execute them.

# %%
# Training function (from train.py)
def run_training():
    """
    Main training function.
    Sets random seeds, creates output directory, trains the model, and tests both saved checkpoints.

    Returns:
        trainer: The trained ChexnetTrainer object
    """
    # Set random seeds for reproducibility
    seed = 1002
    torch.manual_seed(seed)
    np.random.seed(seed)

    # Create output directory for checkpoints
    try:
        os.mkdir(args.save_dir)
    except OSError as error:
        print(error)  # Directory may already exist, that's okay

    # Initialize trainer and start training
    trainer = ChexnetTrainer(args)
    trainer()  # Calls trainer.train() which runs the full training loop

    # After training, test both saved checkpoints
    # Test 1: Model with minimum validation loss
    checkpoint = torch.load(f'{args.save_dir}/min_loss_checkpoint.pth.tar', weights_only=False)
    trainer.model.load_state_dict(checkpoint['state_dict'])
    print('Testing the min loss model')
    test_ind_auroc = trainer.test()
    test_ind_auroc = np.array(test_ind_auroc)

    # Print results for seen and unseen classes
    trainer.print_auroc(test_ind_auroc[trainer.test_dl.dataset.seen_class_ids],
                       trainer.test_dl.dataset.seen_class_ids, prefix='\ntest_seen')
    trainer.print_auroc(test_ind_auroc[trainer.test_dl.dataset.unseen_class_ids],
                       trainer.test_dl.dataset.unseen_class_ids, prefix='\ntest_unseen')

    # Test 2: Model with best AUROC
    checkpoint = torch.load(f'{args.save_dir}/best_auroc_checkpoint.pth.tar', weights_only=False)
    trainer.model.load_state_dict(checkpoint['state_dict'])
    print('Testing the best AUROC model')
    test_ind_auroc = trainer.test()
    test_ind_auroc = np.array(test_ind_auroc)

    # Print results for seen and unseen classes
    trainer.print_auroc(test_ind_auroc[trainer.test_dl.dataset.seen_class_ids],
                       trainer.test_dl.dataset.seen_class_ids, prefix='\ntest_seen')
    trainer.print_auroc(test_ind_auroc[trainer.test_dl.dataset.unseen_class_ids],
                       trainer.test_dl.dataset.unseen_class_ids, prefix='\ntest_unseen')

    return trainer

# Testing function (from test.py)
def run_test(checkpoint_path=None):
    """
    Test a trained model on the test set.
    Loads a checkpoint and evaluates on both seen and unseen classes.

    Args:
        checkpoint_path: Path to checkpoint file. If None, uses the best_auroc checkpoint.

    Returns:
        trainer: The ChexnetTrainer object with loaded model
        test_ind_auroc: Array of AUROC scores for each class
    """
    # Create output directory if it doesn't exist
    try:
        os.mkdir(args.save_dir)
    except OSError as error:
        print(error)  # Directory may already exist

    # Initialize trainer (this loads datasets)
    trainer = ChexnetTrainer(args)

    # Determine which checkpoint to load
    if checkpoint_path is None:
        checkpoint_path = f'{args.save_dir}/best_auroc_checkpoint.pth.tar'

    # Load checkpoint and update model weights
    checkpoint = torch.load(checkpoint_path, weights_only=False)
    trainer.model.load_state_dict(checkpoint['state_dict'])
    print(f'Testing model from checkpoint: {checkpoint_path}')

    # Run test evaluation
    test_ind_auroc = trainer.test()
    test_ind_auroc = np.array(test_ind_auroc)

    # Print results for seen classes (classes available during training)
    trainer.print_auroc(test_ind_auroc[trainer.test_dl.dataset.seen_class_ids],
                       trainer.test_dl.dataset.seen_class_ids, prefix='\ntest_seen')
    # Print results for unseen classes (zero-shot learning evaluation)
    trainer.print_auroc(test_ind_auroc[trainer.test_dl.dataset.unseen_class_ids],
                       trainer.test_dl.dataset.unseen_class_ids, prefix='\ntest_unseen')

    return trainer, test_ind_auroc

# %% [markdown]
# ## Run Training
#
# Execute this cell to start training the model.

# %%
# Run training
# trainer = run_training()

# %%
# Ablation Study Configuration
# Define different loss configurations to test

ablation_configs = [
    {
        'name': 'full_model',
        'description': 'All three loss components (baseline)',
        'beta_rank': 1.0,
        'beta_map': 0.01,
        'beta_con': 0.01,
        'wo_map': False,
        'wo_con': False,
    },
    {
        'name': 'no_alignment',
        'description': 'Without alignment loss (ranking + consistency)',
        'beta_rank': 1.0,
        'beta_map': 0.0,
        'beta_con': 0.01,
        'wo_map': True,
        'wo_con': False,
    },
    {
        'name': 'no_consistency',
        'description': 'Without consistency loss (ranking + alignment)',
        'beta_rank': 1.0,
        'beta_map': 0.01,
        'beta_con': 0.0,
        'wo_map': False,
        'wo_con': True,
    },
    {
        'name': 'no_alignment_no_consistency',
        'description': 'Only ranking loss',
        'beta_rank': 1.0,
        'beta_map': 0.0,
        'beta_con': 0.0,
        'wo_map': True,
        'wo_con': True,
    },
]

# %%
# Run Ablation Study

import json
from copy import deepcopy

ablation_results = {}

# Save original args
original_args = deepcopy(args)

for config in ablation_configs:
    print(f"\n{'='*80}")
    print(f"Training: {config['name']} - {config['description']}")
    print(f"{'='*80}\n")

    # Update args with ablation configuration
    args.beta_rank = config['beta_rank']
    args.beta_map = config['beta_map']
    args.beta_con = config['beta_con']
    args.wo_map = config['wo_map']
    args.wo_con = config['wo_con']

    # Create a separate save directory for this configuration
    original_save_dir = args.save_dir
    args.save_dir = f'{args.save_dir}/ablation_{config["name"]}'

    # Set random seeds for reproducibility
    seed = 1002
    torch.manual_seed(seed)
    np.random.seed(seed)

    # Create output directory
    try:
        os.makedirs(args.save_dir, exist_ok=True)
    except OSError as error:
        print(error)

    # Train the model
    trainer = ChexnetTrainer(args)
    trainer()

    # Test the best model
    checkpoint = torch.load(f'{args.save_dir}/best_auroc_checkpoint.pth.tar', weights_only=False)
    trainer.model.load_state_dict(checkpoint['state_dict'])

    # Evaluate on test set
    test_ind_auroc = trainer.test()
    test_ind_auroc = np.array(test_ind_auroc)

    # Store results
    ablation_results[config['name']] = {
        'description': config['description'],
        'config': config,
        'test_seen_auroc': test_ind_auroc[trainer.test_dl.dataset.seen_class_ids].mean(),
        'test_unseen_auroc': test_ind_auroc[trainer.test_dl.dataset.unseen_class_ids].mean(),
        'test_seen_individual': test_ind_auroc[trainer.test_dl.dataset.seen_class_ids].tolist(),
        'test_unseen_individual': test_ind_auroc[trainer.test_dl.dataset.unseen_class_ids].tolist(),
        'best_epoch': trainer.best_epoch,
        'max_auroc_mean': trainer.max_auroc_mean,
    }

    # Print results
    print(f"\nResults for {config['name']}:")
    print(f"  Test Seen AUROC: {ablation_results[config['name']]['test_seen_auroc']:.4f}")
    print(f"  Test Unseen AUROC: {ablation_results[config['name']]['test_unseen_auroc']:.4f}")

    # Restore original save_dir
    args.save_dir = original_save_dir

# Restore original args
args = original_args

# Save all results to a JSON file
results_file = 'ablation_results.json'
with open(results_file, 'w') as f:
    json.dump(ablation_results, f, indent=2)
print(f"\nAll ablation results saved to {results_file}")
# Out:
# ================================================================================
# Training: full_model - All three loss components (baseline)
# ================================================================================
#
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 197MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# loaded imagenet weights True
#
#
#
# data partition path: dataset_splits/train.txt
# Number of images: 30758
# Number of max labels per image: 7
# Number of classes: 10
# data partition path: dataset_splits/val.txt
# Number of images: 4474
# Number of max labels per image: 6
# Number of classes: 10
# data partition path: dataset_splits/test.txt
# Number of images: 10510
# Number of max labels per image: 7
# Number of classes: 14
# ['Atelectasis', 'Cardiomegaly', 'Effusion', 'Infiltration', 'Mass', 'Nodule', 'Pneumonia', 'Pneumothorax', 'Consolidation', 'Edema', 'Emphysema', 'Fibrosis', 'Pleural_Thickening', 'Hernia']
#  epoch [0001 / 0040] eta: 0 Days 2:12:54       [0009/1923] lr: 	1.0000E-04 loss: 	1.92342
#  epoch [0001 / 0040] eta: 0 Days 2:0:41        [0019/1923] lr: 	1.0000E-04 loss: 	1.58282
#  epoch [0001 / 0040] eta: 0 Days 1:55:27       [0029/1923] lr: 	1.0000E-04 loss: 	1.46174
#  epoch [0001 / 0040] eta: 0 Days 2:10:12       [0039/1923] lr: 	1.0000E-04 loss: 	1.46600
#  epoch [0001 / 0040] eta: 0 Days 2:4:7         [0049/1923] lr: 	1.0000E-04 loss: 	1.44899
#  epoch [0001 / 0040] eta: 0 Days 2:12:47       [0059/1923] lr: 	1.0000E-04 loss: 	1.45325
#  epoch [0001 / 0040] eta: 0 Days 1:54:30       [0069/1923] lr: 	1.0000E-04 loss: 	1.42809
#  epoch [0001 / 0040] eta: 0 Days 1:59:21       [0079/1923] lr: 	1.0000E-04 loss: 	1.41324
#  epoch [0001 / 0040] eta: 0 Days 1:59:17       [0089/1923] lr: 	1.0000E-04 loss: 	1.41153
#  epoch [0001 / 0040] eta: 0 Days 1:58:42       [0099/1923] lr: 	1.0000E-04 loss: 	1.42194
#  epoch [0001 / 0040] eta: 0 Days 1:54:54       [0109/1923] lr: 	1.0000E-04 loss: 	1.42252
#  epoch [0001 / 0040] eta: 0 Days 2:0:22        [0119/1923] lr: 	1.0000E-04 loss: 	1.40850
#  epoch [0001 / 0040] eta: 0 Days 2:19:43       [0129/1923] lr: 	1.0000E-04 loss: 	1.41374
#  epoch [0001 / 0040] eta: 0 Days 2:3:12        [0139/1923] lr: 	1.0000E-04 loss: 	1.40213
#  epoch [0001 / 0040] eta: 0 Days 1:58:3        [0149/1923] lr: 	1.0000E-04 loss: 	1.39334
#  epoch [0001 / 0040] eta: 0 Days 1:56:49       [0159/1923] lr: 	1.0000E-04 loss: 	1.38441
#  epoch [0001 / 0040] eta: 0 Days 1:58:10       [0169/1923] lr: 	1.0000E-04 loss: 	1.38115
#  epoch [0001 / 0040] eta: 0 Days 1:56:18       [0179/1923] lr: 	1.0000E-04 loss: 	1.37353
#  epoch [0001 / 0040] eta: 0 Days 2:10:54       [0189/1923] lr: 	1.0000E-04 loss: 	1.36480
#  epoch [0001 / 0040] eta: 0 Days 1:56:25       [0199/1923] lr: 	1.0000E-04 loss: 	1.36420
#  epoch [0001 / 0040] eta: 0 Days 1:56:31       [0209/1923] lr: 	1.0000E-04 loss: 	1.36690
#  epoch [0001 / 0040] eta: 0 Days 1:59:2        [0219/1923] lr: 	1.0000E-04 loss: 	1.36762
#  epoch [0001 / 0040] eta: 0 Days 1:59:8        [0229/1923] lr: 	1.0000E-04 loss: 	1.35922
#  epoch [0001 / 0040] eta: 0 Days 1:58:45       [0239/1923] lr: 	1.0000E-04 loss: 	1.35608
#  epoch [0001 / 0040] eta: 0 Days 2:9:48        [0249/1923] lr: 	1.0000E-04 loss: 	1.35311
#  epoch [0001 / 0040] eta: 0 Days 2:25:6        [0259/1923] lr: 	1.0000E-04 loss: 	1.35280
#  epoch [0001 / 0040] eta: 0 Days 2:16:37       [0269/1923] lr: 	1.0000E-04 loss: 	1.36558
#  epoch [0001 / 0040] eta: 0 Days 2:3:4         [0279/1923] lr: 	1.0000E-04 loss: 	1.36530
#  epoch [0001 / 0040] eta: 0 Days 2:2:58        [0289/1923] lr: 	1.0000E-04 loss: 	1.36742
#  epoch [0001 / 0040] eta: 0 Days 1:58:15       [0299/1923] lr: 	1.0000E-04 loss: 	1.36418
#  epoch [0001 / 0040] eta: 0 Days 1:54:44       [0309/1923] lr: 	1.0000E-04 loss: 	1.36384
#  epoch [0001 / 0040] eta: 0 Days 1:54:27       [0319/1923] lr: 	1.0000E-04 loss: 	1.35822
#  epoch [0001 / 0040] eta: 0 Days 1:54:32       [0329/1923] lr: 	1.0000E-04 loss: 	1.35646
#  epoch [0001 / 0040] eta: 0 Days 1:54:36       [0339/1923] lr: 	1.0000E-04 loss: 	1.35634
#  epoch [0001 / 0040] eta: 0 Days 1:54:15       [0349/1923] lr: 	1.0000E-04 loss: 	1.35416
#  epoch [0001 / 0040] eta: 0 Days 2:8:13        [0359/1923] lr: 	1.0000E-04 loss: 	1.34544
#  epoch [0001 / 0040] eta: 0 Days 1:55:7        [0369/1923] lr: 	1.0000E-04 loss: 	1.34283
#  epoch [0001 / 0040] eta: 0 Days 2:3:11        [0379/1923] lr: 	1.0000E-04 loss: 	1.34338
#  epoch [0001 / 0040] eta: 0 Days 1:52:37       [0389/1923] lr: 	1.0000E-04 loss: 	1.33692
#  epoch [0001 / 0040] eta: 0 Days 2:7:39        [0399/1923] lr: 	1.0000E-04 loss: 	1.33291
#  epoch [0001 / 0040] eta: 0 Days 1:54:58       [0409/1923] lr: 	1.0000E-04 loss: 	1.33029
#  epoch [0001 / 0040] eta: 0 Days 1:55:6        [0419/1923] lr: 	1.0000E-04 loss: 	1.33364
#  epoch [0001 / 0040] eta: 0 Days 1:57:17       [0429/1923] lr: 	1.0000E-04 loss: 	1.33131
#  epoch [0001 / 0040] eta: 0 Days 1:56:26       [0439/1923] lr: 	1.0000E-04 loss: 	1.33052
#  epoch [0001 / 0040] eta: 0 Days 1:56:59       [0449/1923] lr: 	1.0000E-04 loss: 	1.32916
#  epoch [0001 / 0040] eta: 0 Days 1:54:57       [0459/1923] lr: 	1.0000E-04 loss: 	1.32600
#  epoch [0001 / 0040] eta: 0 Days 1:56:4        [0469/1923] lr: 	1.0000E-04 loss: 	1.32407
#  epoch [0001 / 0040] eta: 0 Days 1:51:55       [0479/1923] lr: 	1.0000E-04 loss: 	1.32168
#  epoch [0001 / 0040] eta: 0 Days 1:55:32       [0489/1923] lr: 	1.0000E-04 loss: 	1.31852
#  epoch [0001 / 0040] eta: 0 Days 1:54:9        [0499/1923] lr: 	1.0000E-04 loss: 	1.31474
#  epoch [0001 / 0040] eta: 0 Days 2:28:57       [0509/1923] lr: 	1.0000E-04 loss: 	1.31310
#  epoch [0001 / 0040] eta: 0 Days 2:2:55        [0519/1923] lr: 	1.0000E-04 loss: 	1.31567
#  epoch [0001 / 0040] eta: 0 Days 1:57:11       [0529/1923] lr: 	1.0000E-04 loss: 	1.31407
#  epoch [0001 / 0040] eta: 0 Days 1:56:28       [0539/1923] lr: 	1.0000E-04 loss: 	1.31391
#  epoch [0001 / 0040] eta: 0 Days 1:55:57       [0549/1923] lr: 	1.0000E-04 loss: 	1.31155
#  epoch [0001 / 0040] eta: 0 Days 1:54:5        [0559/1923] lr: 	1.0000E-04 loss: 	1.30887
#  epoch [0001 / 0040] eta: 0 Days 1:58:11       [0569/1923] lr: 	1.0000E-04 loss: 	1.30826
#  epoch [0001 / 0040] eta: 0 Days 1:56:6        [0579/1923] lr: 	1.0000E-04 loss: 	1.30780
#  epoch [0001 / 0040] eta: 0 Days 1:54:19       [0589/1923] lr: 	1.0000E-04 loss: 	1.30815
#  epoch [0001 / 0040] eta: 0 Days 1:56:45       [0599/1923] lr: 	1.0000E-04 loss: 	1.30896
#  epoch [0001 / 0040] eta: 0 Days 1:54:18       [0609/1923] lr: 	1.0000E-04 loss: 	1.30983
#  epoch [0001 / 0040] eta: 0 Days 1:55:36       [0619/1923] lr: 	1.0000E-04 loss: 	1.31063
#  epoch [0001 / 0040] eta: 0 Days 1:54:43       [0629/1923] lr: 	1.0000E-04 loss: 	1.31149
#  epoch [0001 / 0040] eta: 0 Days 1:55:8        [0639/1923] lr: 	1.0000E-04 loss: 	1.31204
#  epoch [0001 / 0040] eta: 0 Days 1:53:35       [0649/1923] lr: 	1.0000E-04 loss: 	1.31400
#  epoch [0001 / 0040] eta: 0 Days 2:1:23        [0659/1923] lr: 	1.0000E-04 loss: 	1.31206
#  epoch [0001 / 0040] eta: 0 Days 2:9:33        [0669/1923] lr: 	1.0000E-04 loss: 	1.30974
#  epoch [0001 / 0040] eta: 0 Days 1:56:57       [0679/1923] lr: 	1.0000E-04 loss: 	1.30952
#  epoch [0001 / 0040] eta: 0 Days 2:3:2         [0689/1923] lr: 	1.0000E-04 loss: 	1.30938
#  epoch [0001 / 0040] eta: 0 Days 1:55:53       [0699/1923] lr: 	1.0000E-04 loss: 	1.30784
#  epoch [0001 / 0040] eta: 0 Days 1:58:33       [0709/1923] lr: 	1.0000E-04 loss: 	1.30515
#  epoch [0001 / 0040] eta: 0 Days 1:53:31       [0719/1923] lr: 	1.0000E-04 loss: 	1.30488
#  epoch [0001 / 0040] eta: 0 Days 2:1:54        [0729/1923] lr: 	1.0000E-04 loss: 	1.30436
#  epoch [0001 / 0040] eta: 0 Days 1:57:4        [0739/1923] lr: 	1.0000E-04 loss: 	1.30175
#  epoch [0001 / 0040] eta: 0 Days 1:53:28       [0749/1923] lr: 	1.0000E-04 loss: 	1.29991
#  epoch [0001 / 0040] eta: 0 Days 1:53:11       [0759/1923] lr: 	1.0000E-04 loss: 	1.30070
#  epoch [0001 / 0040] eta: 0 Days 1:53:4        [0769/1923] lr: 	1.0000E-04 loss: 	1.30083
#  epoch [0001 / 0040] eta: 0 Days 1:53:10       [0779/1923] lr: 	1.0000E-04 loss: 	1.30062
#  epoch [0001 / 0040] eta: 0 Days 1:58:23       [0789/1923] lr: 	1.0000E-04 loss: 	1.30003
#  epoch [0001 / 0040] eta: 0 Days 1:56:13       [0799/1923] lr: 	1.0000E-04 loss: 	1.29982
#  epoch [0001 / 0040] eta: 0 Days 1:57:40       [0809/1923] lr: 	1.0000E-04 loss: 	1.29907
#  epoch [0001 / 0040] eta: 0 Days 1:52:31       [0819/1923] lr: 	1.0000E-04 loss: 	1.29697
#  epoch [0001 / 0040] eta: 0 Days 1:56:54       [0829/1923] lr: 	1.0000E-04 loss: 	1.29650
#  epoch [0001 / 0040] eta: 0 Days 1:59:3        [0839/1923] lr: 	1.0000E-04 loss: 	1.29530
#  epoch [0001 / 0040] eta: 0 Days 1:58:37       [0849/1923] lr: 	1.0000E-04 loss: 	1.29381
#  epoch [0001 / 0040] eta: 0 Days 1:56:3        [0859/1923] lr: 	1.0000E-04 loss: 	1.29338
#  epoch [0001 / 0040] eta: 0 Days 2:2:6         [0869/1923] lr: 	1.0000E-04 loss: 	1.29372
#  epoch [0001 / 0040] eta: 0 Days 2:3:6         [0879/1923] lr: 	1.0000E-04 loss: 	1.29343
#  epoch [0001 / 0040] eta: 0 Days 1:58:23       [0889/1923] lr: 	1.0000E-04 loss: 	1.29249
#  epoch [0001 / 0040] eta: 0 Days 2:5:28        [0899/1923] lr: 	1.0000E-04 loss: 	1.29212
#  epoch [0001 / 0040] eta: 0 Days 2:5:19        [0909/1923] lr: 	1.0000E-04 loss: 	1.29143
#  epoch [0001 / 0040] eta: 0 Days 1:57:34       [0919/1923] lr: 	1.0000E-04 loss: 	1.29038
#  epoch [0001 / 0040] eta: 0 Days 2:0:24        [0929/1923] lr: 	1.0000E-04 loss: 	1.28872
#  epoch [0001 / 0040] eta: 0 Days 1:57:48       [0939/1923] lr: 	1.0000E-04 loss: 	1.28704
#  epoch [0001 / 0040] eta: 0 Days 1:56:2        [0949/1923] lr: 	1.0000E-04 loss: 	1.28331
#  epoch [0001 / 0040] eta: 0 Days 1:57:27       [0959/1923] lr: 	1.0000E-04 loss: 	1.28110
#  epoch [0001 / 0040] eta: 0 Days 1:57:19       [0969/1923] lr: 	1.0000E-04 loss: 	1.27973
#  epoch [0001 / 0040] eta: 0 Days 1:54:37       [0979/1923] lr: 	1.0000E-04 loss: 	1.27853
#  epoch [0001 / 0040] eta: 0 Days 1:57:0        [0989/1923] lr: 	1.0000E-04 loss: 	1.27787
#  epoch [0001 / 0040] eta: 0 Days 1:55:20       [0999/1923] lr: 	1.0000E-04 loss: 	1.27781
#  epoch [0001 / 0040] eta: 0 Days 2:1:40        [1009/1923] lr: 	1.0000E-04 loss: 	1.27750
#  epoch [0001 / 0040] eta: 0 Days 1:57:27       [1019/1923] lr: 	1.0000E-04 loss: 	1.27803
#  epoch [0001 / 0040] eta: 0 Days 2:6:26        [1029/1923] lr: 	1.0000E-04 loss: 	1.27853
#  epoch [0001 / 0040] eta: 0 Days 2:27:14       [1039/1923] lr: 	1.0000E-04 loss: 	1.27811
#  epoch [0001 / 0040] eta: 0 Days 2:10:10       [1049/1923] lr: 	1.0000E-04 loss: 	1.27913
#  epoch [0001 / 0040] eta: 0 Days 1:51:22       [1059/1923] lr: 	1.0000E-04 loss: 	1.27937
#  epoch [0001 / 0040] eta: 0 Days 1:51:42       [1069/1923] lr: 	1.0000E-04 loss: 	1.27735
#  epoch [0001 / 0040] eta: 0 Days 1:54:44       [1079/1923] lr: 	1.0000E-04 loss: 	1.27638
#  epoch [0001 / 0040] eta: 0 Days 1:54:9        [1089/1923] lr: 	1.0000E-04 loss: 	1.27597
#  epoch [0001 / 0040] eta: 0 Days 1:53:25       [1099/1923] lr: 	1.0000E-04 loss: 	1.27635
#  epoch [0001 / 0040] eta: 0 Days 1:52:51       [1109/1923] lr: 	1.0000E-04 loss: 	1.27575
#  epoch [0001 / 0040] eta: 0 Days 1:53:6        [1119/1923] lr: 	1.0000E-04 loss: 	1.27505
#  epoch [0001 / 0040] eta: 0 Days 1:51:58       [1129/1923] lr: 	1.0000E-04 loss: 	1.27436
#  epoch [0001 / 0040] eta: 0 Days 1:52:38       [1139/1923] lr: 	1.0000E-04 loss: 	1.27225
#  epoch [0001 / 0040] eta: 0 Days 1:51:43       [1149/1923] lr: 	1.0000E-04 loss: 	1.27099
#  epoch [0001 / 0040] eta: 0 Days 1:55:21       [1159/1923] lr: 	1.0000E-04 loss: 	1.27060
#  epoch [0001 / 0040] eta: 0 Days 2:15:23       [1169/1923] lr: 	1.0000E-04 loss: 	1.27075
#  epoch [0001 / 0040] eta: 0 Days 1:56:19       [1179/1923] lr: 	1.0000E-04 loss: 	1.27061
#  epoch [0001 / 0040] eta: 0 Days 1:54:29       [1189/1923] lr: 	1.0000E-04 loss: 	1.27052
#  epoch [0001 / 0040] eta: 0 Days 1:59:11       [1199/1923] lr: 	1.0000E-04 loss: 	1.27162
#  epoch [0001 / 0040] eta: 0 Days 1:53:57       [1209/1923] lr: 	1.0000E-04 loss: 	1.27012
#  epoch [0001 / 0040] eta: 0 Days 2:28:14       [1219/1923] lr: 	1.0000E-04 loss: 	1.26830
#  epoch [0001 / 0040] eta: 0 Days 1:56:4        [1229/1923] lr: 	1.0000E-04 loss: 	1.26779
#  epoch [0001 / 0040] eta: 0 Days 1:51:57       [1239/1923] lr: 	1.0000E-04 loss: 	1.26713
#  epoch [0001 / 0040] eta: 0 Days 1:51:19       [1249/1923] lr: 	1.0000E-04 loss: 	1.26507
#  epoch [0001 / 0040] eta: 0 Days 1:52:28       [1259/1923] lr: 	1.0000E-04 loss: 	1.26488
#  epoch [0001 / 0040] eta: 0 Days 1:53:50       [1269/1923] lr: 	1.0000E-04 loss: 	1.26469
#  epoch [0001 / 0040] eta: 0 Days 1:51:29       [1279/1923] lr: 	1.0000E-04 loss: 	1.26412
#  epoch [0001 / 0040] eta: 0 Days 1:54:9        [1289/1923] lr: 	1.0000E-04 loss: 	1.26288
#  epoch [0001 / 0040] eta: 0 Days 1:52:38       [1299/1923] lr: 	1.0000E-04 loss: 	1.26161
#  epoch [0001 / 0040] eta: 0 Days 2:10:54       [1309/1923] lr: 	1.0000E-04 loss: 	1.25977
#  epoch [0001 / 0040] eta: 0 Days 1:57:18       [1319/1923] lr: 	1.0000E-04 loss: 	1.25902
#  epoch [0001 / 0040] eta: 0 Days 1:53:57       [1329/1923] lr: 	1.0000E-04 loss: 	1.25842
#  epoch [0001 / 0040] eta: 0 Days 1:54:10       [1339/1923] lr: 	1.0000E-04 loss: 	1.25711
#  epoch [0001 / 0040] eta: 0 Days 1:53:27       [1349/1923] lr: 	1.0000E-04 loss: 	1.25680
#  epoch [0001 / 0040] eta: 0 Days 1:51:21       [1359/1923] lr: 	1.0000E-04 loss: 	1.25528
#  epoch [0001 / 0040] eta: 0 Days 1:53:29       [1369/1923] lr: 	1.0000E-04 loss: 	1.25455
#  epoch [0001 / 0040] eta: 0 Days 1:52:11       [1379/1923] lr: 	1.0000E-04 loss: 	1.25334
#  epoch [0001 / 0040] eta: 0 Days 1:53:57       [1389/1923] lr: 	1.0000E-04 loss: 	1.25401
#  epoch [0001 / 0040] eta: 0 Days 1:56:7        [1399/1923] lr: 	1.0000E-04 loss: 	1.25308
#  epoch [0001 / 0040] eta: 0 Days 1:51:22       [1409/1923] lr: 	1.0000E-04 loss: 	1.25362
#  epoch [0001 / 0040] eta: 0 Days 2:5:33        [1419/1923] lr: 	1.0000E-04 loss: 	1.25267
#  epoch [0001 / 0040] eta: 0 Days 1:55:42       [1429/1923] lr: 	1.0000E-04 loss: 	1.25338
#  epoch [0001 / 0040] eta: 0 Days 1:54:59       [1439/1923] lr: 	1.0000E-04 loss: 	1.25341
#  epoch [0001 / 0040] eta: 0 Days 1:53:3        [1449/1923] lr: 	1.0000E-04 loss: 	1.25258
#  epoch [0001 / 0040] eta: 0 Days 1:54:57       [1459/1923] lr: 	1.0000E-04 loss: 	1.25140
#  epoch [0001 / 0040] eta: 0 Days 1:50:33       [1469/1923] lr: 	1.0000E-04 loss: 	1.25162
#  epoch [0001 / 0040] eta: 0 Days 1:51:59       [1479/1923] lr: 	1.0000E-04 loss: 	1.25218
#  epoch [0001 / 0040] eta: 0 Days 1:54:23       [1489/1923] lr: 	1.0000E-04 loss: 	1.25263
#  epoch [0001 / 0040] eta: 0 Days 1:56:11       [1499/1923] lr: 	1.0000E-04 loss: 	1.25250
#  epoch [0001 / 0040] eta: 0 Days 1:56:3        [1509/1923] lr: 	1.0000E-04 loss: 	1.25252
#  epoch [0001 / 0040] eta: 0 Days 1:53:57       [1519/1923] lr: 	1.0000E-04 loss: 	1.25239
#  epoch [0001 / 0040] eta: 0 Days 1:58:9        [1529/1923] lr: 	1.0000E-04 loss: 	1.25250
#  epoch [0001 / 0040] eta: 0 Days 2:5:56        [1539/1923] lr: 	1.0000E-04 loss: 	1.25272
#  epoch [0001 / 0040] eta: 0 Days 2:5:52        [1549/1923] lr: 	1.0000E-04 loss: 	1.25255
#  epoch [0001 / 0040] eta: 0 Days 2:16:51       [1559/1923] lr: 	1.0000E-04 loss: 	1.25190
#  epoch [0001 / 0040] eta: 0 Days 1:53:49       [1569/1923] lr: 	1.0000E-04 loss: 	1.25229
#  epoch [0001 / 0040] eta: 0 Days 1:56:46       [1579/1923] lr: 	1.0000E-04 loss: 	1.25207
#  epoch [0001 / 0040] eta: 0 Days 1:52:40       [1589/1923] lr: 	1.0000E-04 loss: 	1.25156
#  epoch [0001 / 0040] eta: 0 Days 1:51:30       [1599/1923] lr: 	1.0000E-04 loss: 	1.25130
#  epoch [0001 / 0040] eta: 0 Days 1:59:19       [1609/1923] lr: 	1.0000E-04 loss: 	1.25053
#  epoch [0001 / 0040] eta: 0 Days 1:54:3        [1879/1923] lr: 	1.0000E-04 loss: 	1.23706
#  epoch [0001 / 0040] eta: 0 Days 1:55:40       [1889/1923] lr: 	1.0000E-04 loss: 	1.23618
#  epoch [0001 / 0040] eta: 0 Days 1:56:38       [1899/1923] lr: 	1.0000E-04 loss: 	1.23519
#  epoch [0001 / 0040] eta: 0 Days 1:54:18       [1909/1923] lr: 	1.0000E-04 loss: 	1.23502
#  epoch [0001 / 0040] eta: 0 Days 1:48:24       [1919/1923] lr: 	1.0000E-04 loss: 	1.23437
# 100%|██████████| 28/28 [00:47<00:00,  1.69s/it]
# saving last_epoch checkpoint
# saving best_auroc checkpoint
# saving min_loss checkpoint
# val AUROC mean 0.7012
# Atelectasis 0.7234
# Cardiomegaly 0.8193
# Effusion 0.7917
# Infiltration 0.6091
# Mass 0.7000
# Nodule 0.6575
# Pneumothorax 0.7773
# Consolidation 0.6628
# Pleural_Thickening 0.6279
# Hernia 0.6432
# 100%|██████████| 219/219 [01:13<00:00,  2.99it/s]
# test_seen AUROC mean 0.6858
# Atelectasis 0.6982
# Effusion 0.7928
# Infiltration 0.6123
# Mass 0.6356
# Nodule 0.6931
# Pneumothorax 0.7651
# Consolidation 0.6577
# Cardiomegaly 0.8476
# Pleural_Thickening 0.5926
# Hernia 0.5633
#
# test_unseen AUROC mean 0.5936
# Edema 0.6367
# Pneumonia 0.5800
# Emphysema 0.6620
# Fibrosis 0.4958
# best epoch 1 best auroc 0.7012322572342529 loss 1.087790 auroc at min loss 0.7012
#  epoch [0002 / 0040] eta: 0 Days 2:1:15        [0009/1923] lr: 	1.0000E-04 loss: 	1.33644
#  epoch [0002 / 0040] eta: 0 Days 1:52:44       [0019/1923] lr: 	1.0000E-04 loss: 	1.17831
#  epoch [0002 / 0040] eta: 0 Days 1:55:21       [0029/1923] lr: 	1.0000E-04 loss: 	1.14678
#  epoch [0002 / 0040] eta: 0 Days 1:56:24       [0039/1923] lr: 	1.0000E-04 loss: 	1.13831
#  epoch [0002 / 0040] eta: 0 Days 1:54:4        [0049/1923] lr: 	1.0000E-04 loss: 	1.10228
#  epoch [0002 / 0040] eta: 0 Days 1:51:46       [0059/1923] lr: 	1.0000E-04 loss: 	1.12852
#  epoch [0002 / 0040] eta: 0 Days 2:6:0         [0069/1923] lr: 	1.0000E-04 loss: 	1.14269
#  epoch [0002 / 0040] eta: 0 Days 1:54:28       [0079/1923] lr: 	1.0000E-04 loss: 	1.14845
#  epoch [0002 / 0040] eta: 0 Days 1:53:16       [0089/1923] lr: 	1.0000E-04 loss: 	1.13918
#  epoch [0002 / 0040] eta: 0 Days 2:17:19       [0099/1923] lr: 	1.0000E-04 loss: 	1.12599
#  epoch [0002 / 0040] eta: 0 Days 2:30:2        [0109/1923] lr: 	1.0000E-04 loss: 	1.12834
#  epoch [0002 / 0040] eta: 0 Days 1:58:10       [0119/1923] lr: 	1.0000E-04 loss: 	1.13107
#  epoch [0002 / 0040] eta: 0 Days 2:19:5        [0129/1923] lr: 	1.0000E-04 loss: 	1.12263
# Pneumothorax 0.7521
# Consolidation 0.6606
# Pleural_Thickening 0.6326
# Hernia 0.4840
# 100%|██████████| 219/219 [01:06<00:00,  3.28it/s]
# test_seen AUROC mean 0.7009
# Atelectasis 0.7104
# Effusion 0.8015
# Infiltration 0.6531
# Mass 0.6990
# Nodule 0.7247
# Pneumothorax 0.7502
# Consolidation 0.6717
# Cardiomegaly 0.8524
# Pleural_Thickening 0.6157
# Hernia 0.5308
#
# test_unseen AUROC mean 0.6199
# Edema 0.6320
# Pneumonia 0.6160
# Emphysema 0.6653
# Fibrosis 0.5664
# best epoch 2 best auroc 0.7062401412221117 loss 0.987603 auroc at min loss 0.7062
#  epoch [0003 / 0040] eta: 0 Days 1:54:22       [0009/1923] lr: 	1.0000E-04 loss: 	1.14408
#  epoch [0003 / 0040] eta: 0 Days 1:55:12       [0019/1923] lr: 	1.0000E-04 loss: 	1.12692
#  epoch [0003 / 0040] eta: 0 Days 1:52:44       [0029/1923] lr: 	1.0000E-04 loss: 	1.03466
#  epoch [0003 / 0040] eta: 0 Days 1:51:41       [0039/1923] lr: 	1.0000E-04 loss: 	1.02944
#  epoch [0003 / 0040] eta: 0 Days 1:56:49       [0049/1923] lr: 	1.0000E-04 loss: 	1.03041
#  epoch [0003 / 0040] eta: 0 Days 1:53:17       [0059/1923] lr: 	1.0000E-04 loss: 	1.03710
#  epoch [0003 / 0040] eta: 0 Days 1:53:48       [0069/1923] lr: 	1.0000E-04 loss: 	1.02064
#  epoch [0003 / 0040] eta: 0 Days 1:51:5        [0079/1923] lr: 	1.0000E-04 loss: 	1.00726
#  epoch [0003 / 0040] eta: 0 Days 1:49:2        [0089/1923] lr: 	1.0000E-04 loss: 	1.00439
#  epoch [0003 / 0040] eta: 0 Days 1:51:28       [0099/1923] lr: 	1.0000E-04 loss: 	1.01364
#  epoch [0003 / 0040] eta: 0 Days 1:48:48       [0109/1923] lr: 	1.0000E-04 loss: 	1.02919
#  epoch [0003 / 0040] eta: 0 Days 1:49:25       [0119/1923] lr: 	1.0000E-04 loss: 	1.04355
#  epoch [0003 / 0040] eta: 0 Days 1:49:6        [0129/1923] lr: 	1.0000E-04 loss: 	1.05596
#  epoch [0003 / 0040] eta: 0 Days 1:47:30       [0139/1923] lr: 	1.0000E-04 loss: 	1.05570
#  epoch [0003 / 0040] eta: 0 Days 1:52:19       [0149/1923] lr: 	1.0000E-04 loss: 	1.05166
#  epoch [0003 / 0040] eta: 0 Days 1:54:54       [0159/1923] lr: 	1.0000E-04 loss: 	1.04111
#  epoch [0003 / 0040] eta: 0 Days 2:6:32        [0169/1923] lr: 	1.0000E-04 loss: 	1.04247
#  epoch [0003 / 0040] eta: 0 Days 1:53:3        [0179/1923] lr: 	1.0000E-04 loss: 	1.04390
#  epoch [0003 / 0040] eta: 0 Days 1:54:7        [0189/1923] lr: 	1.0000E-04 loss: 	1.04732
#  epoch [0003 / 0040] eta: 0 Days 1:50:38       [0199/1923] lr: 	1.0000E-04 loss: 	1.04827
#  epoch [0003 / 0040] eta: 0 Days 2:19:50       [0469/1923] lr: 	1.0000E-04 loss: 	1.06280
#  epoch [0003 / 0040] eta: 0 Days 2:1:47        [0479/1923] lr: 	1.0000E-04 loss: 	1.06046
#  epoch [0003 / 0040] eta: 0 Days 1:53:17       [0489/1923] lr: 	1.0000E-04 loss: 	1.06001
#  epoch [0003 / 0040] eta: 0 Days 1:53:22       [0499/1923] lr: 	1.0000E-04 loss: 	1.05988
#  epoch [0003 / 0040] eta: 0 Days 1:53:48       [0509/1923] lr: 	1.0000E-04 loss: 	1.05871
#  epoch [0003 / 0040] eta: 0 Days 1:54:44       [0519/1923] lr: 	1.0000E-04 loss: 	1.05789
#  epoch [0003 / 0040] eta: 0 Days 1:54:40       [0529/1923] lr: 	1.0000E-04 loss: 	1.05863
#  epoch [0003 / 0040] eta: 0 Days 1:54:7        [0539/1923] lr: 	1.0000E-04 loss: 	1.05745
#  epoch [0003 / 0040] eta: 0 Days 1:53:31       [0549/1923] lr: 	1.0000E-04 loss: 	1.05465
#  epoch [0003 / 0040] eta: 0 Days 1:49:13       [0559/1923] lr: 	1.0000E-04 loss: 	1.05691
#  epoch [0003 / 0040] eta: 0 Days 1:50:22       [0569/1923] lr: 	1.0000E-04 loss: 	1.05367
#  epoch [0003 / 0040] eta: 0 Days 1:48:44       [0579/1923] lr: 	1.0000E-04 loss: 	1.05031
#  epoch [0003 / 0040] eta: 0 Days 1:50:38       [0589/1923] lr: 	1.0000E-04 loss: 	1.04851
#  epoch [0003 / 0040] eta: 0 Days 1:57:2        [0599/1923] lr: 	1.0000E-04 loss: 	1.04927
#  epoch [0003 / 0040] eta: 0 Days 1:51:33       [0609/1923] lr: 	1.0000E-04 loss: 	1.05036
#  epoch [0003 / 0040] eta: 0 Days 1:48:46       [0619/1923] lr: 	1.0000E-04 loss: 	1.05070
#  epoch [0003 / 0040] eta: 0 Days 1:47:21       [0629/1923] lr: 	1.0000E-04 loss: 	1.05191
#  epoch [0003 / 0040] eta: 0 Days 1:49:25       [0639/1923] lr: 	1.0000E-04 loss: 	1.05307
#  epoch [0003 / 0040] eta: 0 Days 1:48:59       [0649/1923] lr: 	1.0000E-04 loss: 	1.05378
#  epoch [0003 / 0040] eta: 0 Days 1:52:50       [0659/1923] lr: 	1.0000E-04 loss: 	1.05238
#  epoch [0003 / 0040] eta: 0 Days 1:50:16       [0669/1923] lr: 	1.0000E-04 loss: 	1.05163
#  epoch [0003 / 0040] eta: 0 Days 1:52:16       [0679/1923] lr: 	1.0000E-04 loss: 	1.04939
#  epoch [0003 / 0040] eta: 0 Days 1:50:16       [0689/1923] lr: 	1.0000E-04 loss: 	1.05045
#  epoch [0003 / 0040] eta: 0 Days 1:47:28       [0699/1923] lr: 	1.0000E-04 loss: 	1.05019
#  epoch [0003 / 0040] eta: 0 Days 1:49:24       [0709/1923] lr: 	1.0000E-04 loss: 	1.05105
#  epoch [0003 / 0040] eta: 0 Days 1:51:42       [0719/1923] lr: 	1.0000E-04 loss: 	1.05146
#  epoch [0003 / 0040] eta: 0 Days 2:4:20        [0729/1923] lr: 	1.0000E-04 loss: 	1.05210
#  epoch [0003 / 0040] eta: 0 Days 1:49:5        [0739/1923] lr: 	1.0000E-04 loss: 	1.05008
#  epoch [0003 / 0040] eta: 0 Days 1:48:41       [0749/1923] lr: 	1.0000E-04 loss: 	1.04898
#  epoch [0003 / 0040] eta: 0 Days 1:50:1        [0759/1923] lr: 	1.0000E-04 loss: 	1.04893
#  epoch [0003 / 0040] eta: 0 Days 1:51:6        [0769/1923] lr: 	1.0000E-04 loss: 	1.04930
#  epoch [0003 / 0040] eta: 0 Days 1:52:6        [0779/1923] lr: 	1.0000E-04 loss: 	1.04876
#  epoch [0003 / 0040] eta: 0 Days 1:56:45       [0789/1923] lr: 	1.0000E-04 loss: 	1.04740
#  epoch [0003 / 0040] eta: 0 Days 1:51:3        [0799/1923] lr: 	1.0000E-04 loss: 	1.04946
#  epoch [0003 / 0040] eta: 0 Days 1:52:43       [0809/1923] lr: 	1.0000E-04 loss: 	1.05177
#  epoch [0003 / 0040] eta: 0 Days 1:53:7        [0819/1923] lr: 	1.0000E-04 loss: 	1.05217
#  epoch [0003 / 0040] eta: 0 Days 1:50:46       [0829/1923] lr: 	1.0000E-04 loss: 	1.05265
#  epoch [0003 / 0040] eta: 0 Days 1:56:17       [0839/1923] lr: 	1.0000E-04 loss: 	1.05147
#  epoch [0003 / 0040] eta: 0 Days 1:52:34       [0849/1923] lr: 	1.0000E-04 loss: 	1.05117
#  epoch [0003 / 0040] eta: 0 Days 1:54:10       [0859/1923] lr: 	1.0000E-04 loss: 	1.05216
#  epoch [0003 / 0040] eta: 0 Days 1:51:22       [0869/1923] lr: 	1.0000E-04 loss: 	1.05219
#  epoch [0003 / 0040] eta: 0 Days 1:51:43       [0879/1923] lr: 	1.0000E-04 loss: 	1.05051
#  epoch [0003 / 0040] eta: 0 Days 1:53:4        [0889/1923] lr: 	1.0000E-04 loss: 	1.05047
#  epoch [0003 / 0040] eta: 0 Days 1:51:27       [0899/1923] lr: 	1.0000E-04 loss: 	1.04919
#  epoch [0003 / 0040] eta: 0 Days 1:51:50       [0909/1923] lr: 	1.0000E-04 loss: 	1.04981
#  epoch [0003 / 0040] eta: 0 Days 1:48:59       [0919/1923] lr: 	1.0000E-04 loss: 	1.05064
#  epoch [0003 / 0040] eta: 0 Days 1:49:21       [0929/1923] lr: 	1.0000E-04 loss: 	1.05197
#  epoch [0003 / 0040] eta: 0 Days 1:50:41       [0939/1923] lr: 	1.0000E-04 loss: 	1.05037
#  epoch [0003 / 0040] eta: 0 Days 1:54:16       [0949/1923] lr: 	1.0000E-04 loss: 	1.05139
#  epoch [0003 / 0040] eta: 0 Days 1:53:4        [0959/1923] lr: 	1.0000E-04 loss: 	1.04973
#  epoch [0003 / 0040] eta: 0 Days 1:49:1        [0969/1923] lr: 	1.0000E-04 loss: 	1.04922
#  epoch [0003 / 0040] eta: 0 Days 2:13:4        [0979/1923] lr: 	1.0000E-04 loss: 	1.04783
#  epoch [0003 / 0040] eta: 0 Days 1:48:29       [0989/1923] lr: 	1.0000E-04 loss: 	1.04882
#  epoch [0003 / 0040] eta: 0 Days 1:50:4        [0999/1923] lr: 	1.0000E-04 loss: 	1.04845
#  epoch [0003 / 0040] eta: 0 Days 1:50:10       [1009/1923] lr: 	1.0000E-04 loss: 	1.04937
#  epoch [0003 / 0040] eta: 0 Days 1:49:58       [1019/1923] lr: 	1.0000E-04 loss: 	1.04959
#  epoch [0003 / 0040] eta: 0 Days 1:49:51       [1029/1923] lr: 	1.0000E-04 loss: 	1.04994
#  epoch [0003 / 0040] eta: 0 Days 2:3:46        [1039/1923] lr: 	1.0000E-04 loss: 	1.05006
#  epoch [0003 / 0040] eta: 0 Days 1:48:47       [1049/1923] lr: 	1.0000E-04 loss: 	1.05085
#  epoch [0003 / 0040] eta: 0 Days 1:48:4        [1059/1923] lr: 	1.0000E-04 loss: 	1.05165
#  epoch [0003 / 0040] eta: 0 Days 1:47:54       [1069/1923] lr: 	1.0000E-04 loss: 	1.05159
#  epoch [0003 / 0040] eta: 0 Days 1:47:45       [1079/1923] lr: 	1.0000E-04 loss: 	1.05198
#  epoch [0003 / 0040] eta: 0 Days 1:48:29       [1089/1923] lr: 	1.0000E-04 loss: 	1.05253
#  epoch [0003 / 0040] eta: 0 Days 1:52:26       [1099/1923] lr: 	1.0000E-04 loss: 	1.05294
#  epoch [0003 / 0040] eta: 0 Days 1:47:47       [1109/1923] lr: 	1.0000E-04 loss: 	1.05207
# ...
#  epoch [0003 / 0040] eta: 0 Days 1:54:15       [0469/1923] lr: 	1.0000E-04 loss: 	0.01007
#  epoch [0003 / 0040] eta: 0 Days 1:55:30       [0479/1923] lr: 	1.0000E-04 loss: 	0.01007
#  epoch [0003 / 0040] eta: 0 Days 2:2:34        [0489/1923] lr: 	1.0000E-04 loss: 	0.01007
#  epoch [0003 / 0040] eta: 0 Days 1:55:57       [0499/1923] lr: 	1.0000E-04 loss: 	0.01007
#  epoch [0003 / 0040] eta: 0 Days 2:1:12        [0509/1923] lr: 	1.0000E-04 loss: 	0.01007
#  epoch [0003 / 0040] eta: 0 Days 1:56:51       [0519/1923] lr: 	1.0000E-04 loss: 	0.01007
#  epoch [0003 / 0040] eta: 0 Days 1:53:11       [0529/1923] lr: 	1.0000E-04 loss: 	0.01006
#  epoch [0003 / 0040] eta: 0 Days 1:52:24       [0539/1923] lr: 	1.0000E-04 loss: 	0.01006
#  epoch [0003 / 0040] eta: 0 Days 1:53:48       [0549/1923] lr: 	1.0000E-04 loss: 	0.01006
#  epoch [0003 / 0040] eta: 0 Days 1:53:45       [0559/1923] lr: 	1.0000E-04 loss: 	0.01006
#  epoch [0003 / 0040] eta: 0 Days 1:55:27       [0569/1923] lr: 	1.0000E-04 loss: 	0.01005
#  epoch [0003 / 0040] eta: 0 Days 1:55:6        [0579/1923] lr: 	1.0000E-04 loss: 	0.01005
#  epoch [0003 / 0040] eta: 0 Days 1:56:58       [0589/1923] lr: 	1.0000E-04 loss: 	0.01005
1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:57:2        [1259/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:44       [1269/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:34       [1279/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:47       [1289/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:13       [1299/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:1        [1309/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:31       [1319/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 2:5:52        [1329/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:52       [1339/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:38       [1349/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:50       [1359/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:49:34       [1369/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:39       [1379/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:38       [1389/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:55:54       [1399/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:20       [1409/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:49:26       [1419/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:48:13       [1429/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:24       [1439/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:36       [1449/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:49:19       [1459/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 2:1:37        [1469/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:1        [1479/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:55       [1489/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:58:18       [1499/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:47       [1509/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:5        [1519/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:23       [1529/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:38       [1539/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:54:58       [1549/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:54:54       [1559/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:56:28       [1569/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:55:26       [1579/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:49       [1589/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:14       [1599/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:35       [1609/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:23       [1619/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:25       [1629/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:34       [1639/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:19       [1649/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:43       [1659/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:57       [1669/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:59       [1679/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:55:42       [1689/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:32       [1699/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:48       [1709/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:58:17       [1719/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:49:38       [1729/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:14       [1739/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:34       [1749/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:9        [1759/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:9        [1769/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:11       [1779/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:0        [1789/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:14       [1799/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:46       [1809/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:52:26       [1819/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:5        [1829/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 2:0:24        [1839/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:54:37       [1849/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:56:14       [1859/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:25       [1869/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:50:18       [1879/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:11       [1889/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:51:24       [1899/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:53:11       [1909/1923] lr: 	1.0000E-04 loss: 	nan
#  epoch [0003 / 0040] eta: 0 Days 1:47:49       [1919/1923] lr: 	1.0000E-04 loss: 	nan
# 100%|██████████| 28/28 [00:47<00:00,  1.70s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2235542801.py in <cell line: 0>()
#      38     # Train the model
#      39     trainer = ChexnetTrainer(args)
# ---> 40     trainer()
#      41
#      42     # Test the best model
#
# /tmp/ipython-input-2632396797.py in __call__(self)
#      79
#      80     def __call__(self):
# ---> 81         self.train()
#      82
#      83     def step_lr(self, epoch):
#
# /tmp/ipython-input-2632396797.py in train(self)
#     164
#     165             # Validate on validation set
# --> 166             lossVal, val_ind_auroc = self.epochVal()
#     167             val_ind_auroc = np.array(val_ind_auroc)
#     168
#
# /tmp/ipython-input-2632396797.py in epochVal(self)
#     328
#     329         # Compute AUROC for each class
# --> 330         aurocIndividual = self.computeAUROC(outGT, outPRED, self.val_dl.dataset.class_ids_loaded)
#     331
#     332         # Track validation loss for plotting
#
# /tmp/ipython-input-2632396797.py in computeAUROC(self, dataGT, dataPRED, class_ids)
#     401         for i in class_ids:
#     402             # AUROC for binary classification: true labels vs predicted scores for class i
# --> 403             auroc = roc_auc_score(datanpGT[:, i], datanpPRED[:, i])
#     404             outAUROC.append(auroc)
#     405
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     618     y_type = type_of_target(y_true, input_name="y_true")
#     619     y_true = check_array(y_true, ensure_2d=False, dtype=None)
# --> 620     y_score = check_array(y_score, ensure_2d=False)
#     621
#     622     if y_type == "multiclass" or (
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1105
#    1106         if ensure_all_finite:
# -> 1107             _assert_all_finite(
#    1108                 array,
#    1109                 input_name=input_name,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     118         return
#     119
# --> 120     _assert_all_finite_element_wise(
#     121         X,
#     122         xp=xp,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     167                 "#estimators-that-handle-nan-values"
#     168             )
# --> 169         raise ValueError(msg_err)
#     170
#     171
#
# ValueError: Input contains NaN.

# %%
# Visualize Ablation Study Results
# Compare performance across different loss configurations

import matplotlib.pyplot as plt
import pandas as pd

# Create a summary DataFrame
summary_data = []
for name, results in ablation_results.items():
    summary_data.append({
        'Configuration': name,
        'Description': results['description'],
        'Test Seen AUROC': results['test_seen_auroc'],
        'Test Unseen AUROC': results['test_unseen_auroc'],
        'Ranking Loss': 'Yes' if results['config']['beta_rank'] > 0 else 'No',
        'Alignment Loss': 'Yes' if results['config']['beta_map'] > 0 else 'No',
        'Consistency Loss': 'Yes' if results['config']['beta_con'] > 0 else 'No',
    })

df = pd.DataFrame(summary_data)
print("\nAblation Study Summary:")
print("="*100)
print(df.to_string(index=False))
print("="*100)

# Create visualization
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Bar chart comparing seen and unseen AUROC
x = np.arange(len(ablation_results))
width = 0.35

seen_aurocs = [results['test_seen_auroc'] for results in ablation_results.values()]
unseen_aurocs = [results['test_unseen_auroc'] for results in ablation_results.values()]
config_names = [name.replace('_', ' ').title() for name in ablation_results.keys()]

axes[0].bar(x - width/2, seen_aurocs, width, label='Seen Classes', alpha=0.8)
axes[0].bar(x + width/2, unseen_aurocs, width, label='Unseen Classes', alpha=0.8)
axes[0].set_xlabel('Configuration')
axes[0].set_ylabel('AUROC')
axes[0].set_title('Ablation Study: Test AUROC by Configuration')
axes[0].set_xticks(x)
axes[0].set_xticklabels(config_names, rotation=45, ha='right')
axes[0].legend()
axes[0].grid(axis='y', alpha=0.3)

# Plot 2: Heatmap showing which loss components are active
loss_components = ['Ranking', 'Alignment', 'Consistency']
config_matrix = []
for name, results in ablation_results.items():
    config_matrix.append([
        1 if results['config']['beta_rank'] > 0 else 0,
        1 if results['config']['beta_map'] > 0 else 0,
        1 if results['config']['beta_con'] > 0 else 0,
    ])

im = axes[1].imshow(config_matrix, cmap='RdYlGn', aspect='auto', vmin=0, vmax=1)
axes[1].set_xticks(np.arange(len(loss_components)))
axes[1].set_yticks(np.arange(len(config_names)))
axes[1].set_xticklabels(loss_components)
axes[1].set_yticklabels(config_names)
axes[1].set_title('Loss Components Active in Each Configuration')
axes[1].set_xlabel('Loss Component')
axes[1].set_ylabel('Configuration')

# Add text annotations
for i in range(len(config_names)):
    for j in range(len(loss_components)):
        text = axes[1].text(j, i, '✓' if config_matrix[i][j] else '✗',
                          ha="center", va="center", color="black", fontsize=14)

plt.tight_layout()
plt.savefig('ablation_study_results.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nVisualization saved as 'ablation_study_results.png'")

# %% [markdown]
# ## Run Testing
#
# Execute this cell to test a trained model. You can specify a checkpoint path, or it will use the best_auroc checkpoint by default.

# %%
# Run testing
# Option 1: Test with default checkpoint (best_auroc)
# trainer, test_results = run_test()

# Option 2: Test with a specific checkpoint
# trainer, test_results = run_test(checkpoint_path='checkpoints/best_auroc_checkpoint.pth.tar')
# trainer, test_results = run_test(checkpoint_path='checkpoints/min_loss_checkpoint.pth.tar')
